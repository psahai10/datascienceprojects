# %% [markdown]
# # Programming Assignment
#
# ## Saving and loading models, with application to the EuroSat dataset
#
# ### Instructions
#
# In this notebook, you will create a neural network that classifies land uses and land covers from satellite imagery. You will save your model using Tensorflow's callbacks and reload it later. You will also load in a pre-trained neural network classifier and compare performance with it.
#
# Some code cells are provided for you in the notebook. You should avoid editing provided code, and make sure to execute the cells in order to avoid unexpected errors. Some cells begin with the line:
#
# `#### GRADED CELL ####`
#
# Don't move or edit this first line - this is what the automatic grader looks for to recognise graded cells. These cells require you to write your own code to complete them, and are automatically graded when you submit the notebook. Don't edit the function name or signature provided in these cells, otherwise the automatic grader might not function properly. Inside these graded cells, you can use any functions or classes that are imported below, but make sure you don't use any variables that are outside the scope of the function.
#
# ### How to submit
#
# Complete all the tasks you are asked for in the worksheet. When you have finished and are happy with your code, press the **Submit Assignment** button at the top of this notebook.
#
# ### Let's get started!
#
# We'll start running some imports, and loading the dataset. Do not edit the existing imports in the following cell. If you would like to make further Tensorflow imports, you should add them here.

# %%
#### PACKAGE IMPORTS ####

# Run this cell first to import all required packages. Do not make any imports elsewhere in the notebook

import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import os
import numpy as np
import pandas as pd

# If you would like to make further imports from tensorflow, add them here

# %% [markdown]
# ![EuroSAT overview image](data/eurosat_overview.jpg)
#
# #### The EuroSAT dataset
#
# In this assignment, you will use the [EuroSAT dataset](https://github.com/phelber/EuroSAT). It consists of 27000 labelled Sentinel-2 satellite images of different land uses: residential, industrial, highway, river, forest, pasture, herbaceous vegetation, annual crop, permanent crop and sea/lake. For a reference, see the following papers:
# - Eurosat: A novel dataset and deep learning benchmark for land use and land cover classification. Patrick Helber, Benjamin Bischke, Andreas Dengel, Damian Borth. IEEE Journal of Selected Topics in Applied Earth Observations and Remote Sensing, 2019.
# - Introducing EuroSAT: A Novel Dataset and Deep Learning Benchmark for Land Use and Land Cover Classification. Patrick Helber, Benjamin Bischke, Andreas Dengel. 2018 IEEE International Geoscience and Remote Sensing Symposium, 2018.
#
# Your goal is to construct a neural network that classifies a satellite image into one of these 10 classes, as well as applying some of the saving and loading techniques you have learned in the previous sessions.

# %% [markdown]
# #### Import the data
#
# The dataset you will train your model on is a subset of the total data, with 4000 training images and 1000 testing images, with roughly equal numbers of each class. The code to import the data is provided below.

# %%
# Run this cell to import the Eurosat data

def load_eurosat_data():
    data_dir = 'data/'
    x_train = np.load(os.path.join(data_dir, 'x_train.npy'))
    y_train = np.load(os.path.join(data_dir, 'y_train.npy'))
    x_test  = np.load(os.path.join(data_dir, 'x_test.npy'))
    y_test  = np.load(os.path.join(data_dir, 'y_test.npy'))
    return (x_train, y_train), (x_test, y_test)

(x_train, y_train), (x_test, y_test) = load_eurosat_data()
x_train = x_train / 255.0
x_test = x_test / 255.0

# %% [markdown]
# #### Build the neural network model

# %% [markdown]
# You can now construct a model to fit to the data. Using the Sequential API, build your model according to the following specifications:
#
# * The model should use the input_shape in the function argument to set the input size in the first layer.
# * The first layer should be a Conv2D layer with 16 filters, a 3x3 kernel size, a ReLU activation function and 'SAME' padding. Name this layer 'conv_1'.
# * The second layer should also be a Conv2D layer with 8 filters, a 3x3 kernel size, a ReLU activation function and 'SAME' padding. Name this layer 'conv_2'.
# * The third layer should be a MaxPooling2D layer with a pooling window size of 8x8. Name this layer 'pool_1'.
# * The fourth layer should be a Flatten layer, named 'flatten'.
# * The fifth layer should be a Dense layer with 32 units, a ReLU activation. Name this layer 'dense_1'.
# * The sixth and final layer should be a Dense layer with 10 units and softmax activation. Name this layer 'dense_2'.
#
# In total, the network should have 6 layers.

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def get_new_model(input_shape):
    """
    This function should build a Sequential model according to the above specification. Ensure the 
    weights are initialised by providing the input_shape argument in the first layer, given by the
    function argument.
    Your function should also compile the model with the Adam optimiser, sparse categorical cross
    entropy loss function, and a single accuracy metric.
    """
    
    model = tf.keras.models.Sequential([
      tf.keras.layers.Conv2D(16, (3,3), activation='relu', padding='same',
                             input_shape=(input_shape), name='conv_1'),
      tf.keras.layers.Conv2D(8, (3,3), activation='relu', padding='same',
                             input_shape=(input_shape), name='conv_2'),
      tf.keras.layers.MaxPooling2D((8,8), name='pool_1'),
      tf.keras.layers.Flatten(name='flatten'),
      tf.keras.layers.Dense(32, activation='relu', name='dense_1'),
      tf.keras.layers.Dense(10, activation='softmax', name='dense_2')
    ])
    
    model.compile(optimizer='adam',
                loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])
    return model

# %% [markdown]
# #### Compile and evaluate the model

# %%
# Run your function to create the model

model = get_new_model(x_train[0].shape)

# %%
# Run this cell to define a function to evaluate a model's test accuracy

def get_test_accuracy(model, x_test, y_test):
    """Test model classification accuracy"""
    test_loss, test_acc = model.evaluate(x=x_test, y=y_test, verbose=0)
    print('accuracy: {acc:0.3f}'.format(acc=test_acc))

# %%
# Print the model summary and calculate its initialised test accuracy

model.summary()
get_test_accuracy(model, x_test, y_test)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_1 (Conv2D)              (None, 64, 64, 16)        448
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 64, 64, 8)         1160
# _________________________________________________________________
# pool_1 (MaxPooling2D)        (None, 8, 8, 8)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                16416
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 18,354
# Trainable params: 18,354
# Non-trainable params: 0
# _________________________________________________________________
# accuracy: 0.091

# %%
# ! mkdir checkpoints_best_only

# %% [markdown]
# #### Create checkpoints to save model during training, with a criterion
#
# You will now create three callbacks:
# - `checkpoint_every_epoch`: checkpoint that saves the model weights every epoch during training
# - `checkpoint_best_only`: checkpoint that saves only the weights with the highest validation accuracy. Use the testing data as the validation data.
# - `early_stopping`: early stopping object that ends training if the validation accuracy has not improved in 3 epochs.

# %%
# #### GRADED CELL ####

# Complete the following functions. 
# Make sure to not change the function names or arguments.

def get_checkpoint_every_epoch():
    """
    This function should return a ModelCheckpoint object that:
    - saves the weights only at the end of every epoch
    - saves into a directory called 'checkpoints_every_epoch' inside the current working directory
    - generates filenames in that directory like 'checkpoint_XXX' where
      XXX is the epoch number formatted to have three digits, e.g. 001, 002, 003, etc.
    """
    checkpoint_path_epoch = 'checkpoints_every_epoch/checkpoint_{epoch:03d}'
    return ModelCheckpoint(filepath=checkpoint_path_epoch,
                            frequency='epoch',
                            save_weights_only=True,
                             verbose=1)
    

def get_checkpoint_best_only():
    """
    This function should return a ModelCheckpoint object that:
    - saves only the weights that generate the highest validation (testing) accuracy
    - saves into a directory called 'checkpoints_best_only' inside the current working directory
    - generates a file called 'checkpoints_best_only/checkpoint' 
    """
    checkpoint_path_best = 'checkpoints_best_only/checkpoint'
    return ModelCheckpoint(filepath=checkpoint_path_best,        
                            save_weights_only=True,
                            save_freq='epoch',
                            monitor='val_accuracy',
                            save_best_only=True,
                            verbose=1)

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.
from tensorflow.keras.callbacks import EarlyStopping
def get_early_stopping():
    """
    This function should return an EarlyStopping callback that stops training when
    the validation (testing) accuracy has not improved in the last 3 epochs.
    HINT: use the EarlyStopping callback with the correct 'monitor' and 'patience'
    """
    early_stopping = EarlyStopping(monitor='val_accuracy', patience=3)
    return early_stopping

# %%
# Run this cell to create the callbacks

checkpoint_every_epoch = get_checkpoint_every_epoch()
checkpoint_best_only = get_checkpoint_best_only()
early_stopping = get_early_stopping()

# %% [markdown]
# #### Train model using the callbacks
#
# Now, you will train the model using the three callbacks you created. If you created the callbacks correctly, three things should happen:
# - At the end of every epoch, the model weights are saved into a directory called `checkpoints_every_epoch`
# - At the end of every epoch, the model weights are saved into a directory called `checkpoints_best_only` **only** if those weights lead to the highest test accuracy
# - Training stops when the testing accuracy has not improved in three epochs.
#
# You should then have two directories:
# - A directory called `checkpoints_every_epoch` containing filenames that include `checkpoint_001`, `checkpoint_002`, etc with the `001`, `002` corresponding to the epoch
# - A directory called `checkpoints_best_only` containing filenames that include `checkpoint`, which contain only the weights leading to the highest testing accuracy

# %%
# Train model using the callbacks you just created
checkpoint_path_best = 'checkpoints_best_only/checkpoint'
checkpoint_best_only = ModelCheckpoint(filepath=checkpoint_path_best,        
                            save_weights_only=True,
                            save_freq='epoch',
                            monitor='val_accuracy',
                            save_best_only=True,
                            verbose=1)

callbacks = [checkpoint_best_only, checkpoint_every_epoch, early_stopping]
model.fit(x_train, y_train, epochs=50, validation_data=(x_test, y_test), callbacks=callbacks)
# Out:
# Train on 4000 samples, validate on 1000 samples
# Epoch 1/50
# 3968/4000 [============================>.] - ETA: 1s - loss: 1.9405 - sparse_categorical_accuracy: 0.2863WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00001: saving model to checkpoints_every_epoch/checkpoint_001
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 194s 49ms/sample - loss: 1.9372 - sparse_categorical_accuracy: 0.2875 - val_loss: 1.6277 - val_sparse_categorical_accuracy: 0.3880
# Epoch 2/50
# 3968/4000 [============================>.] - ETA: 1s - loss: 1.4206 - sparse_categorical_accuracy: 0.4556WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00002: saving model to checkpoints_every_epoch/checkpoint_002
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 151s 38ms/sample - loss: 1.4192 - sparse_categorical_accuracy: 0.4568 - val_loss: 1.5103 - val_sparse_categorical_accuracy: 0.4330
# Epoch 3/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 1.3153 - sparse_categorical_accuracy: 0.4945WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00003: saving model to checkpoints_every_epoch/checkpoint_003
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 135s 34ms/sample - loss: 1.3158 - sparse_categorical_accuracy: 0.4947 - val_loss: 1.3086 - val_sparse_categorical_accuracy: 0.5290
# Epoch 4/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 1.2302 - sparse_categorical_accuracy: 0.5449WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00004: saving model to checkpoints_every_epoch/checkpoint_004
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 115s 29ms/sample - loss: 1.2303 - sparse_categorical_accuracy: 0.5450 - val_loss: 1.3856 - val_sparse_categorical_accuracy: 0.4860
# Epoch 5/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 1.1575 - sparse_categorical_accuracy: 0.5731WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00005: saving model to checkpoints_every_epoch/checkpoint_005
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 103s 26ms/sample - loss: 1.1573 - sparse_categorical_accuracy: 0.5727 - val_loss: 1.2425 - val_sparse_categorical_accuracy: 0.5340
# Epoch 6/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 1.1126 - sparse_categorical_accuracy: 0.6008WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00006: saving model to checkpoints_every_epoch/checkpoint_006
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 106s 26ms/sample - loss: 1.1139 - sparse_categorical_accuracy: 0.6000 - val_loss: 1.1586 - val_sparse_categorical_accuracy: 0.5840
# Epoch 7/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 1.0455 - sparse_categorical_accuracy: 0.6215WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00007: saving model to checkpoints_every_epoch/checkpoint_007
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 112s 28ms/sample - loss: 1.0469 - sparse_categorical_accuracy: 0.6210 - val_loss: 1.1726 - val_sparse_categorical_accuracy: 0.5720
# Epoch 8/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 1.0481 - sparse_categorical_accuracy: 0.6295WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00008: saving model to checkpoints_every_epoch/checkpoint_008
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 109s 27ms/sample - loss: 1.0477 - sparse_categorical_accuracy: 0.6295 - val_loss: 1.0994 - val_sparse_categorical_accuracy: 0.5830
# Epoch 9/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.9542 - sparse_categorical_accuracy: 0.6502WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00009: saving model to checkpoints_every_epoch/checkpoint_009
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 110s 27ms/sample - loss: 0.9573 - sparse_categorical_accuracy: 0.6490 - val_loss: 1.0323 - val_sparse_categorical_accuracy: 0.6280
# Epoch 10/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.9188 - sparse_categorical_accuracy: 0.6711WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00010: saving model to checkpoints_every_epoch/checkpoint_010
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 114s 29ms/sample - loss: 0.9187 - sparse_categorical_accuracy: 0.6715 - val_loss: 0.9624 - val_sparse_categorical_accuracy: 0.6580
# Epoch 11/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.8971 - sparse_categorical_accuracy: 0.6726WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00011: saving model to checkpoints_every_epoch/checkpoint_011
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 105s 26ms/sample - loss: 0.8966 - sparse_categorical_accuracy: 0.6733 - val_loss: 0.9354 - val_sparse_categorical_accuracy: 0.6740
# Epoch 12/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.8503 - sparse_categorical_accuracy: 0.6938WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00012: saving model to checkpoints_every_epoch/checkpoint_012
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 103s 26ms/sample - loss: 0.8514 - sparse_categorical_accuracy: 0.6935 - val_loss: 0.9004 - val_sparse_categorical_accuracy: 0.6670
# Epoch 13/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.8115 - sparse_categorical_accuracy: 0.7094WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00013: saving model to checkpoints_every_epoch/checkpoint_013
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 111s 28ms/sample - loss: 0.8103 - sparse_categorical_accuracy: 0.7100 - val_loss: 0.9140 - val_sparse_categorical_accuracy: 0.6490
# Epoch 14/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.7898 - sparse_categorical_accuracy: 0.7140WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00014: saving model to checkpoints_every_epoch/checkpoint_014
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 104s 26ms/sample - loss: 0.7889 - sparse_categorical_accuracy: 0.7138 - val_loss: 0.8602 - val_sparse_categorical_accuracy: 0.6960
# Epoch 15/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.7858 - sparse_categorical_accuracy: 0.7150WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00015: saving model to checkpoints_every_epoch/checkpoint_015
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 102s 26ms/sample - loss: 0.7867 - sparse_categorical_accuracy: 0.7147 - val_loss: 0.8549 - val_sparse_categorical_accuracy: 0.6880
# Epoch 16/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.7660 - sparse_categorical_accuracy: 0.7218WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00016: saving model to checkpoints_every_epoch/checkpoint_016
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 101s 25ms/sample - loss: 0.7650 - sparse_categorical_accuracy: 0.7218 - val_loss: 0.8287 - val_sparse_categorical_accuracy: 0.7040
# Epoch 17/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.7250 - sparse_categorical_accuracy: 0.7382WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00017: saving model to checkpoints_every_epoch/checkpoint_017
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 104s 26ms/sample - loss: 0.7249 - sparse_categorical_accuracy: 0.7377 - val_loss: 0.8043 - val_sparse_categorical_accuracy: 0.7090
# Epoch 18/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.7187 - sparse_categorical_accuracy: 0.7359WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00018: saving model to checkpoints_every_epoch/checkpoint_018
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 99s 25ms/sample - loss: 0.7185 - sparse_categorical_accuracy: 0.7365 - val_loss: 0.8103 - val_sparse_categorical_accuracy: 0.7090
# Epoch 19/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.7060 - sparse_categorical_accuracy: 0.7422WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00019: saving model to checkpoints_every_epoch/checkpoint_019
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 103s 26ms/sample - loss: 0.7069 - sparse_categorical_accuracy: 0.7418 - val_loss: 0.7903 - val_sparse_categorical_accuracy: 0.7230
# Epoch 20/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.6974 - sparse_categorical_accuracy: 0.7432WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00020: saving model to checkpoints_every_epoch/checkpoint_020
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 107s 27ms/sample - loss: 0.6976 - sparse_categorical_accuracy: 0.7433 - val_loss: 0.8795 - val_sparse_categorical_accuracy: 0.6680
# Epoch 21/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.6777 - sparse_categorical_accuracy: 0.7563WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00021: saving model to checkpoints_every_epoch/checkpoint_021
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 101s 25ms/sample - loss: 0.6793 - sparse_categorical_accuracy: 0.7555 - val_loss: 0.7923 - val_sparse_categorical_accuracy: 0.7190
# Epoch 22/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.6776 - sparse_categorical_accuracy: 0.7520WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00022: saving model to checkpoints_every_epoch/checkpoint_022
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 102s 26ms/sample - loss: 0.6806 - sparse_categorical_accuracy: 0.7508 - val_loss: 0.8173 - val_sparse_categorical_accuracy: 0.7110
# Epoch 23/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.6570 - sparse_categorical_accuracy: 0.7623WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00023: saving model to checkpoints_every_epoch/checkpoint_023
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 102s 26ms/sample - loss: 0.6562 - sparse_categorical_accuracy: 0.7623 - val_loss: 0.8088 - val_sparse_categorical_accuracy: 0.7270
# Epoch 24/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.6438 - sparse_categorical_accuracy: 0.7692WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00024: saving model to checkpoints_every_epoch/checkpoint_024
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 102s 25ms/sample - loss: 0.6460 - sparse_categorical_accuracy: 0.7673 - val_loss: 0.7867 - val_sparse_categorical_accuracy: 0.7140
# Epoch 25/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.6395 - sparse_categorical_accuracy: 0.7659WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00025: saving model to checkpoints_every_epoch/checkpoint_025
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 102s 25ms/sample - loss: 0.6395 - sparse_categorical_accuracy: 0.7660 - val_loss: 0.8779 - val_sparse_categorical_accuracy: 0.6990
# Epoch 26/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.5963 - sparse_categorical_accuracy: 0.7886WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00026: saving model to checkpoints_every_epoch/checkpoint_026
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 100s 25ms/sample - loss: 0.5969 - sparse_categorical_accuracy: 0.7883 - val_loss: 0.8045 - val_sparse_categorical_accuracy: 0.7190
# Epoch 27/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.5973 - sparse_categorical_accuracy: 0.7855WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00027: saving model to checkpoints_every_epoch/checkpoint_027
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 105s 26ms/sample - loss: 0.5993 - sparse_categorical_accuracy: 0.7850 - val_loss: 0.8795 - val_sparse_categorical_accuracy: 0.6960
# Epoch 28/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.6013 - sparse_categorical_accuracy: 0.7860WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00028: saving model to checkpoints_every_epoch/checkpoint_028
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 106s 27ms/sample - loss: 0.6004 - sparse_categorical_accuracy: 0.7865 - val_loss: 0.7663 - val_sparse_categorical_accuracy: 0.7300
# Epoch 29/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.5967 - sparse_categorical_accuracy: 0.7820WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00029: saving model to checkpoints_every_epoch/checkpoint_029
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 105s 26ms/sample - loss: 0.5969 - sparse_categorical_accuracy: 0.7822 - val_loss: 0.7632 - val_sparse_categorical_accuracy: 0.7380
# Epoch 30/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.5937 - sparse_categorical_accuracy: 0.7843WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00030: saving model to checkpoints_every_epoch/checkpoint_030
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 103s 26ms/sample - loss: 0.5930 - sparse_categorical_accuracy: 0.7845 - val_loss: 0.7854 - val_sparse_categorical_accuracy: 0.7230
# Epoch 31/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.5606 - sparse_categorical_accuracy: 0.7994WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00031: saving model to checkpoints_every_epoch/checkpoint_031
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 100s 25ms/sample - loss: 0.5601 - sparse_categorical_accuracy: 0.7997 - val_loss: 0.7587 - val_sparse_categorical_accuracy: 0.7370
# Epoch 32/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.5628 - sparse_categorical_accuracy: 0.7991WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00032: saving model to checkpoints_every_epoch/checkpoint_032
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 107s 27ms/sample - loss: 0.5614 - sparse_categorical_accuracy: 0.7997 - val_loss: 0.7486 - val_sparse_categorical_accuracy: 0.7560
# Epoch 33/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.5342 - sparse_categorical_accuracy: 0.8120WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00033: saving model to checkpoints_every_epoch/checkpoint_033
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 102s 25ms/sample - loss: 0.5348 - sparse_categorical_accuracy: 0.8123 - val_loss: 0.7793 - val_sparse_categorical_accuracy: 0.7310
# Epoch 34/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.5421 - sparse_categorical_accuracy: 0.8042WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00034: saving model to checkpoints_every_epoch/checkpoint_034
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 102s 26ms/sample - loss: 0.5405 - sparse_categorical_accuracy: 0.8048 - val_loss: 0.7888 - val_sparse_categorical_accuracy: 0.7240
# Epoch 35/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.5209 - sparse_categorical_accuracy: 0.8097WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00035: saving model to checkpoints_every_epoch/checkpoint_035
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 101s 25ms/sample - loss: 0.5207 - sparse_categorical_accuracy: 0.8098 - val_loss: 0.7183 - val_sparse_categorical_accuracy: 0.7630
# Epoch 36/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.5297 - sparse_categorical_accuracy: 0.8092WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00036: saving model to checkpoints_every_epoch/checkpoint_036
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 101s 25ms/sample - loss: 0.5309 - sparse_categorical_accuracy: 0.8085 - val_loss: 0.7632 - val_sparse_categorical_accuracy: 0.7430
# Epoch 37/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.5165 - sparse_categorical_accuracy: 0.8133WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00037: saving model to checkpoints_every_epoch/checkpoint_037
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 102s 25ms/sample - loss: 0.5156 - sparse_categorical_accuracy: 0.8140 - val_loss: 0.7715 - val_sparse_categorical_accuracy: 0.7530
# Epoch 38/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.5026 - sparse_categorical_accuracy: 0.8243WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00038: saving model to checkpoints_every_epoch/checkpoint_038
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 102s 25ms/sample - loss: 0.5022 - sparse_categorical_accuracy: 0.8245 - val_loss: 0.7954 - val_sparse_categorical_accuracy: 0.7280
# Epoch 39/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.4889 - sparse_categorical_accuracy: 0.8238WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00039: saving model to checkpoints_every_epoch/checkpoint_039
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 115s 29ms/sample - loss: 0.4906 - sparse_categorical_accuracy: 0.8232 - val_loss: 0.7679 - val_sparse_categorical_accuracy: 0.7530
# Epoch 40/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.4734 - sparse_categorical_accuracy: 0.8286WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00040: saving model to checkpoints_every_epoch/checkpoint_040
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 110s 27ms/sample - loss: 0.4736 - sparse_categorical_accuracy: 0.8285 - val_loss: 0.7634 - val_sparse_categorical_accuracy: 0.7460
# Epoch 41/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.4662 - sparse_categorical_accuracy: 0.8329WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00041: saving model to checkpoints_every_epoch/checkpoint_041
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 104s 26ms/sample - loss: 0.4656 - sparse_categorical_accuracy: 0.8335 - val_loss: 0.7487 - val_sparse_categorical_accuracy: 0.7640
# Epoch 42/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.4602 - sparse_categorical_accuracy: 0.8385WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00042: saving model to checkpoints_every_epoch/checkpoint_042
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 106s 26ms/sample - loss: 0.4616 - sparse_categorical_accuracy: 0.8382 - val_loss: 0.7809 - val_sparse_categorical_accuracy: 0.7380
# Epoch 43/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.4619 - sparse_categorical_accuracy: 0.8377WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00043: saving model to checkpoints_every_epoch/checkpoint_043
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 99s 25ms/sample - loss: 0.4606 - sparse_categorical_accuracy: 0.8380 - val_loss: 0.8100 - val_sparse_categorical_accuracy: 0.7390
# Epoch 44/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.4523 - sparse_categorical_accuracy: 0.8359WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00044: saving model to checkpoints_every_epoch/checkpoint_044
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 102s 26ms/sample - loss: 0.4546 - sparse_categorical_accuracy: 0.8350 - val_loss: 0.7449 - val_sparse_categorical_accuracy: 0.7620
# Epoch 45/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.4394 - sparse_categorical_accuracy: 0.8488WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00045: saving model to checkpoints_every_epoch/checkpoint_045
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 107s 27ms/sample - loss: 0.4389 - sparse_categorical_accuracy: 0.8493 - val_loss: 0.7687 - val_sparse_categorical_accuracy: 0.7510
# Epoch 46/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.4481 - sparse_categorical_accuracy: 0.8450WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00046: saving model to checkpoints_every_epoch/checkpoint_046
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 109s 27ms/sample - loss: 0.4480 - sparse_categorical_accuracy: 0.8453 - val_loss: 0.8297 - val_sparse_categorical_accuracy: 0.7280
# Epoch 47/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.4335 - sparse_categorical_accuracy: 0.8430WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00047: saving model to checkpoints_every_epoch/checkpoint_047
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 110s 27ms/sample - loss: 0.4339 - sparse_categorical_accuracy: 0.8430 - val_loss: 0.7985 - val_sparse_categorical_accuracy: 0.7340
# Epoch 48/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.4408 - sparse_categorical_accuracy: 0.8458WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00048: saving model to checkpoints_every_epoch/checkpoint_048
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 107s 27ms/sample - loss: 0.4411 - sparse_categorical_accuracy: 0.8457 - val_loss: 0.7519 - val_sparse_categorical_accuracy: 0.7620
# Epoch 49/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.3980 - sparse_categorical_accuracy: 0.8632WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00049: saving model to checkpoints_every_epoch/checkpoint_049
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 112s 28ms/sample - loss: 0.3990 - sparse_categorical_accuracy: 0.8633 - val_loss: 0.7639 - val_sparse_categorical_accuracy: 0.7670
# Epoch 50/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.3959 - sparse_categorical_accuracy: 0.8621WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#
# Epoch 00050: saving model to checkpoints_every_epoch/checkpoint_050
# WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
# 4000/4000 [==============================] - 105s 26ms/sample - loss: 0.3950 - sparse_categorical_accuracy: 0.8625 - val_loss: 0.8074 - val_sparse_categorical_accuracy: 0.7270

# %%
! ls
# Out:
#  checkpoints_every_epoch   data   models  'Week 4 Programming Assignment.ipynb'

# %%
# ! rm -r checkpoints_every_epoch   #checkpoints_best_only

# %% [markdown]
# #### Create new instance of model and load on both sets of weights
#
# Now you will use the weights you just saved in a fresh model. You should create two functions, both of which take a freshly instantiated model instance:
# - `model_last_epoch` should contain the weights from the latest saved epoch
# - `model_best_epoch` should contain the weights from the saved epoch with the highest testing accuracy
#
# _Hint: use the_ `tf.train.latest_checkpoint` _function to get the filename of the latest saved checkpoint file. Check the docs_ [_here_](https://www.tensorflow.org/api_docs/python/tf/train/latest_checkpoint).

# %%
#### GRADED CELL ####

# Complete the following functions. 
# Make sure to not change the function name or arguments.
from tensorflow.keras.models import load_model

def get_model_last_epoch(model):
    """
    This function should create a new instance of the CNN you created earlier,
    load on the weights from the last training epoch, and return this model.
    """
    checkpoint_path = 'checkpoints_every_epoch'
#     model = get_new_model(x_train[0].shape)
    model.load_weights(tf.train.latest_checkpoint(checkpoint_dir=checkpoint_path))
    return model
    
    
def get_model_best_epoch(model):
    """
    This function should create a new instance of the CNN you created earlier, load 
    on the weights leading to the highest validation accuracy, and return this model.
    """
    checkpoint_path = 'checkpoints_best_only/checkpoint'
#     model = get_new_model(x_train[0].shape)
    model.load_weights(checkpoint_path)
    return model

# %%
# Run this cell to create two models: one with the weights from the last training
# epoch, and one with the weights leading to the highest validation (testing) accuracy.
# Verify that the second has a higher validation (testing) accuarcy.

model_last_epoch = get_model_last_epoch(get_new_model(x_train[0].shape))
# model_best_epoch = get_model_best_epoch(get_new_model(x_train[0].shape))
print('Model with last epoch weights:')
get_test_accuracy(model_last_epoch, x_test, y_test)
# print('')
# print('Model with best epoch weights:')
# get_test_accuracy(model_best_epoch, x_test, y_test)
# Out:
# Model with last epoch weights:
# accuracy: 0.727

# %% [markdown]
# #### Load, from scratch, a model trained on the EuroSat dataset.
#
# In your workspace, you will find another model trained on the `EuroSAT` dataset in `.h5` format. This model is trained on a larger subset of the EuroSAT dataset and has a more complex architecture. The path to the model is `models/EuroSatNet.h5`. See how its testing accuracy compares to your model!

# %%
#### GRADED CELL ####

# Complete the following functions. 
# Make sure to not change the function name or arguments.

def get_model_eurosatnet():
    """
    This function should return the pretrained EuroSatNet.h5 model.
    """
    checkpoint_path = 'models/EuroSatNet.h5'
    model = load_model(checkpoint_path)
    return model

# %%
# Run this cell to print a summary of the EuroSatNet model, along with its validation accuracy.

model_eurosatnet = get_model_eurosatnet()
model_eurosatnet.summary()
get_test_accuracy(model_eurosatnet, x_test, y_test)
# Out:
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_1 (Conv2D)              (None, 64, 64, 16)        448
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 64, 64, 16)        6416
# _________________________________________________________________
# pool_1 (MaxPooling2D)        (None, 32, 32, 16)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 32, 32, 16)        2320
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 32, 32, 16)        6416
# _________________________________________________________________
# pool_2 (MaxPooling2D)        (None, 16, 16, 16)        0
# _________________________________________________________________
# conv_5 (Conv2D)              (None, 16, 16, 16)        2320
# _________________________________________________________________
# conv_6 (Conv2D)              (None, 16, 16, 16)        6416
# _________________________________________________________________
# pool_3 (MaxPooling2D)        (None, 8, 8, 16)          0
# _________________________________________________________________
# conv_7 (Conv2D)              (None, 8, 8, 16)          2320
# _________________________________________________________________
# conv_8 (Conv2D)              (None, 8, 8, 16)          6416
# _________________________________________________________________
# pool_4 (MaxPooling2D)        (None, 4, 4, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                8224
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 41,626
# Trainable params: 41,626
# Non-trainable params: 0
# _________________________________________________________________
# accuracy: 0.810

# %% [markdown]
# Congratulations for completing this programming assignment! You're now ready to move on to the capstone project for this course.
