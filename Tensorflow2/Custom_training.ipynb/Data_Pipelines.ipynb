# %% [markdown]
# # Programming Assignment

# %% [markdown]
# ## Data pipeline with Keras and tf.data

# %% [markdown]
# ### Instructions
#
# In this notebook, you will implement a data processing pipeline using tools from both Keras and the tf.data module. You will use the `ImageDataGenerator` class in the tf.keras module to feed a network with training and test images from a local directory containing a subset of the LSUN dataset, and train the model both with and without data augmentation. You will then use the `map` and `filter` functions of the `Dataset` class with the CIFAR-100 dataset to train a network to classify a processed subset of the images.
#
# Some code cells are provided you in the notebook. You should avoid editing provided code, and make sure to execute the cells in order to avoid unexpected errors. Some cells begin with the line:
#
# `#### GRADED CELL ####`
#
# Don't move or edit this first line - this is what the automatic grader looks for to recognise graded cells. These cells require you to write your own code to complete them, and are automatically graded when you submit the notebook. Don't edit the function name or signature provided in these cells, otherwise the automatic grader might not function properly. Inside these graded cells, you can use any functions or classes that are imported below, but make sure you don't use any variables that are outside the scope of the function.
#
# ### How to submit
#
# Complete all the tasks you are asked for in the worksheet. When you have finished and are happy with your code, press the **Submit Assignment** button at the top of this notebook.
#
# ### Let's get started!
#
# We'll start running some imports, and loading the dataset. Do not edit the existing imports in the following cell. If you would like to make further Tensorflow imports, you should add them here.

# %%
#### PACKAGE IMPORTS ####

# Run this cell first to import all required packages. Do not make any imports elsewhere in the notebook

import tensorflow as tf
from tensorflow.keras.datasets import cifar100
import numpy as np
import matplotlib.pyplot as plt
import json
# %matplotlib inline

# If you would like to make further imports from tensorflow, add them here

# %% [markdown]
# ### Part 1: tf.keras
# <table><tr>
# <td> <img src="data/lsun/church.png" alt="Church" style="height: 210px;"/>  </td>
# <td> <img src="data/lsun/classroom.png" alt="Classroom" style="height: 210px;"/> </td>
#     <td> <img src="data/lsun/conference_room.png" alt="Conference Room" style="height: 210px;"/> </td>
# </tr></table>
#
# #### The LSUN Dataset
#
# In the first part of this assignment, you will use a subset of the [LSUN dataset](https://www.yf.io/p/lsun). This is a large-scale image dataset with 10 scene and 20 object categories. A subset of the LSUN dataset has been provided, and has already been split into training and test sets. The three classes included in the subset are `church_outdoor`, `classroom` and `conference_room`.
#
# * F. Yu, A. Seff, Y. Zhang, S. Song, T. Funkhouser and J. Xia. "LSUN: Construction of a Large-scale Image Dataset using Deep Learning with Humans in the Loop". arXiv:1506.03365, 10 Jun 2015
#
# Your goal is to use the Keras preprocessing tools to construct a data ingestion and augmentation pipeline to train a neural network to classify the images into the three classes.

# %%
# Save the directory locations for the training, validation and test sets

train_dir = 'data/lsun/train'
valid_dir = 'data/lsun/valid'
test_dir = 'data/lsun/test'

# %% [markdown]
# #### Create a data generator using the ImageDataGenerator class

# %% [markdown]
# You should first write a function that creates an `ImageDataGenerator` object, which rescales the image pixel values by a factor of 1/255.

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

from tensorflow.keras.preprocessing.image import ImageDataGenerator
def get_ImageDataGenerator():
    """
    This function should return an instance of the ImageDataGenerator class.
    This instance should be set up to rescale the data with the above scaling factor.
    """
    return ImageDataGenerator(rescale=1./255)

# %%
# Call the function to get an ImageDataGenerator as specified

image_gen = get_ImageDataGenerator()

# %% [markdown]
# You should now write a function that returns a generator object that will yield batches of images and labels from the training and test set directories. The generators should:
#
# * Generate batches of size 20.
# * Resize the images to 64 x 64 x 3.
# * Return one-hot vectors for labels. These should be encoded as follows:
#     * `classroom` $\rightarrow$ `[1., 0., 0.]`
#     * `conference_room` $\rightarrow$ `[0., 1., 0.]`
#     * `church_outdoor` $\rightarrow$ `[0., 0., 1.]`
# * Pass in an optional random `seed` for shuffling (this should be passed into the `flow_from_directory` method).
#
# **Hint:** you may need to refer to the [documentation](https://keras.io/preprocessing/image/#imagedatagenerator-class) for the `ImageDataGenerator`.

# %%
#### GRADED CELL ####

# Complete the following function.
# Make sure not to change the function name or arguments.

def get_generator(image_data_generator, directory, seed=None):
    """
    This function takes an ImageDataGenerator object in the first argument and a 
    directory path in the second argument.
    It should use the ImageDataGenerator to return a generator object according 
    to the above specifications. 
    The seed argument should be passed to the flow_from_directory method.
    """
    classes=['classroom','conference_room','church_outdoor']
    data_generator = image_data_generator.flow_from_directory(
                        directory,
                        target_size=(64,64,),
                        batch_size=20,
                        classes=classes,
                        class_mode='categorical',
                        seed=seed)
    return data_generator

# %%
# Run this cell to define training and validation generators

train_generator = get_generator(image_gen, train_dir)
valid_generator = get_generator(image_gen, valid_dir)
# Out:
# Found 300 images belonging to 3 classes.
# Found 120 images belonging to 3 classes.

# %% [markdown]
# We are using a small subset of the dataset for demonstrative purposes in this assignment.

# %% [markdown]
# #### Display sample images and labels from the training set
#
# The following cell depends on your function `get_generator` to be implemented correctly. If it raises an error, go back and check the function specifications carefully.

# %%
# Display a few images and labels from the training set

batch = next(train_generator)
batch_images = np.array(batch[0])
batch_labels = np.array(batch[1])
lsun_classes = ['classroom', 'conference_room', 'church_outdoor']

plt.figure(figsize=(16,10))
for i in range(20):
    ax = plt.subplot(4, 5, i+1)
    plt.imshow(batch_images[i])
    plt.title(lsun_classes[np.where(batch_labels[i] == 1.)[0][0]])
    plt.axis('off')

# %%
# Reset the training generator

train_generator = get_generator(image_gen, train_dir)
# Out:
# Found 300 images belonging to 3 classes.

# %% [markdown]
# #### Build the neural network model
#
# You will now build and compile a convolutional neural network classifier. Using the functional API, build your model according to the following specifications:
#
# * The model should use the `input_shape` in the function argument to define the Input layer.
# * The first hidden layer should be a Conv2D layer with 8 filters, a 8x8 kernel size.
# * The second hidden layer should be a MaxPooling2D layer with a 2x2 pooling window size.
# * The third hidden layer should be a Conv2D layer with 4 filters, a 4x4 kernel size.
# * The fourth hidden layer should be a MaxPooling2D layer with a 2x2 pooling window size.
# * This should be followed by a Flatten layer, and then a Dense layer with 16 units and ReLU activation.
# * The final layer should be a Dense layer with 3 units and softmax activation.
# * All Conv2D layers should use `"SAME"` padding and a ReLU activation function.
#
# In total, the network should have 8 layers. The model should then be compiled with the Adam optimizer with learning rate 0.0005, categorical cross entropy loss, and categorical accuracy metric.

# %%
#### GRADED CELL ####

# Complete the following function.
# Make sure not to change the function name or arguments.
from tensorflow.keras.models import  Sequential, Model
from tensorflow.keras import Input, layers
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
def get_model(input_shape):
    """
    This function should build and compile a CNN model according to the above specification,
    using the functional API. Your function should return the model.
    """
    visible = Input(shape=input_shape) #0
    conv1 = Conv2D(8, kernel_size=(8,8), activation='relu', padding='same')(visible) #1
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1) #2
    conv2 = Conv2D(4, kernel_size=(4,4), activation='relu', padding='same')(pool1) #3
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2) #4
    flat = Flatten()(pool2) #5
    hidden1 = Dense(16, activation='relu')(flat) #6
    output = Dense(3, activation='softmax')(hidden1) #7
    model = Model(inputs=visible, outputs=output)
    model.compile(optimizer=tf.keras.optimizers.Adam(5e-4),
             loss=[tf.keras.losses.CategoricalCrossentropy()],
              metrics=[tf.keras.metrics.CategoricalAccuracy()])
    return model

# %%
# Build and compile the model, print the model summary

lsun_model = get_model((64, 64, 3))
lsun_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 64, 64, 8)         1544
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 32, 32, 8)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 32, 32, 4)         516
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 16, 16, 4)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                16400
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 51
# =================================================================
# Total params: 18,511
# Trainable params: 18,511
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Train the neural network model
#
# You should now write a function to train the model for a specified number of epochs (specified in the `epochs` argument). The function takes a `model` argument, as well as `train_gen` and `valid_gen` arguments for the training and validation generators respectively, which you should use for training and validation data in the training run. You should also use the following callbacks:
#
# * An `EarlyStopping` callback that monitors the validation accuracy and has patience set to 10.
# * A `ReduceLROnPlateau` callback that monitors the validation loss and has the factor set to 0.5 and minimum learning set to 0.0001
#
# Your function should return the training history.

# %%
#### GRADED CELL ####

# Complete the following function.
# Make sure not to change the function name or arguments.
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
def train_model(model, train_gen, valid_gen, epochs):
    """
    This function should define the callback objects specified above, and then use the
    train_gen and valid_gen generator object arguments to train the model for the (maximum) 
    number of epochs specified in the function argument, using the defined callbacks.
    The function should return the training history.
    """
    early_stoppage = EarlyStopping(patience=10, monitor='val_accuracy')
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5,  min_lr=0.0001)
    callbacks = [early_stoppage, reduce_lr]
    
    history = model.fit(
        train_gen, 
        epochs=epochs, 
        validation_data=valid_gen,
        callbacks = callbacks
    )
    return history

# %%
# Train the model for (maximum) 50 epochs

history = train_model(lsun_model, train_generator, valid_generator, epochs=50)
# Out:
# Train for 15 steps, validate for 6 steps
# Epoch 1/50
# 14/15 [===========================>..] - ETA: 8s - loss: 1.1021 - categorical_accuracy: 0.3286 WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 142s 9s/step - loss: 1.1000 - categorical_accuracy: 0.3333 - val_loss: 1.0742 - val_categorical_accuracy: 0.4667
# Epoch 2/50
# 14/15 [===========================>..] - ETA: 2s - loss: 1.0432 - categorical_accuracy: 0.4571WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 53s 4s/step - loss: 1.0408 - categorical_accuracy: 0.4667 - val_loss: 1.0107 - val_categorical_accuracy: 0.5333
# Epoch 3/50
# 14/15 [===========================>..] - ETA: 2s - loss: 0.9269 - categorical_accuracy: 0.5607WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 56s 4s/step - loss: 0.9195 - categorical_accuracy: 0.5633 - val_loss: 0.8822 - val_categorical_accuracy: 0.5833
# Epoch 4/50
# 14/15 [===========================>..] - ETA: 3s - loss: 0.7892 - categorical_accuracy: 0.6321WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 63s 4s/step - loss: 0.7930 - categorical_accuracy: 0.6233 - val_loss: 0.8242 - val_categorical_accuracy: 0.5917
# Epoch 5/50
# 14/15 [===========================>..] - ETA: 2s - loss: 0.6918 - categorical_accuracy: 0.6929WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 59s 4s/step - loss: 0.6994 - categorical_accuracy: 0.6933 - val_loss: 0.8728 - val_categorical_accuracy: 0.6417
# Epoch 6/50
# 14/15 [===========================>..] - ETA: 1s - loss: 0.6435 - categorical_accuracy: 0.7036WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 25s 2s/step - loss: 0.6359 - categorical_accuracy: 0.7067 - val_loss: 0.8205 - val_categorical_accuracy: 0.6000
# Epoch 7/50
# 14/15 [===========================>..] - ETA: 1s - loss: 0.5883 - categorical_accuracy: 0.7214WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 37s 2s/step - loss: 0.6088 - categorical_accuracy: 0.7100 - val_loss: 0.7923 - val_categorical_accuracy: 0.6417
# Epoch 8/50
# 14/15 [===========================>..] - ETA: 2s - loss: 0.5680 - categorical_accuracy: 0.7643WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 49s 3s/step - loss: 0.5840 - categorical_accuracy: 0.7633 - val_loss: 0.8800 - val_categorical_accuracy: 0.6500
# Epoch 9/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5757 - categorical_accuracy: 0.7571WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 11s 753ms/step - loss: 0.5759 - categorical_accuracy: 0.7533 - val_loss: 0.7923 - val_categorical_accuracy: 0.6583
# Epoch 10/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5355 - categorical_accuracy: 0.7643WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 9s 627ms/step - loss: 0.5412 - categorical_accuracy: 0.7600 - val_loss: 0.9101 - val_categorical_accuracy: 0.6167
# Epoch 11/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5221 - categorical_accuracy: 0.7857WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 9s 627ms/step - loss: 0.5098 - categorical_accuracy: 0.7933 - val_loss: 0.8400 - val_categorical_accuracy: 0.6500
# Epoch 12/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.4959 - categorical_accuracy: 0.8107WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 9s 627ms/step - loss: 0.4971 - categorical_accuracy: 0.8100 - val_loss: 0.9329 - val_categorical_accuracy: 0.6500
# Epoch 13/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5382 - categorical_accuracy: 0.7536WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 9s 633ms/step - loss: 0.5297 - categorical_accuracy: 0.7600 - val_loss: 0.8413 - val_categorical_accuracy: 0.6750
# Epoch 14/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.4515 - categorical_accuracy: 0.8036WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 9s 627ms/step - loss: 0.4654 - categorical_accuracy: 0.8000 - val_loss: 0.9054 - val_categorical_accuracy: 0.6667
# Epoch 15/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.4420 - categorical_accuracy: 0.8429WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 9s 627ms/step - loss: 0.4416 - categorical_accuracy: 0.8400 - val_loss: 0.8931 - val_categorical_accuracy: 0.6750
# Epoch 16/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.4120 - categorical_accuracy: 0.8500WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 9s 627ms/step - loss: 0.4169 - categorical_accuracy: 0.8467 - val_loss: 0.9062 - val_categorical_accuracy: 0.6417
# Epoch 17/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.4164 - categorical_accuracy: 0.8179WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 9s 620ms/step - loss: 0.4338 - categorical_accuracy: 0.8067 - val_loss: 0.8791 - val_categorical_accuracy: 0.6417
# Epoch 18/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.3826 - categorical_accuracy: 0.8607WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 9s 626ms/step - loss: 0.3787 - categorical_accuracy: 0.8667 - val_loss: 0.8882 - val_categorical_accuracy: 0.6500
# Epoch 19/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.3705 - categorical_accuracy: 0.8679WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 9s 620ms/step - loss: 0.3681 - categorical_accuracy: 0.8700 - val_loss: 0.9607 - val_categorical_accuracy: 0.6333
# Epoch 20/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.3597 - categorical_accuracy: 0.8750WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 9s 627ms/step - loss: 0.3622 - categorical_accuracy: 0.8700 - val_loss: 0.9152 - val_categorical_accuracy: 0.6583
# Epoch 21/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.3378 - categorical_accuracy: 0.8857WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 640ms/step - loss: 0.3376 - categorical_accuracy: 0.8867 - val_loss: 0.9448 - val_categorical_accuracy: 0.6667
# Epoch 22/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.3374 - categorical_accuracy: 0.8643WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 9s 620ms/step - loss: 0.3340 - categorical_accuracy: 0.8700 - val_loss: 0.9961 - val_categorical_accuracy: 0.6667
# Epoch 23/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.3552 - categorical_accuracy: 0.8714WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 9s 627ms/step - loss: 0.3565 - categorical_accuracy: 0.8667 - val_loss: 1.0607 - val_categorical_accuracy: 0.6333
# Epoch 24/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.3358 - categorical_accuracy: 0.8929WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 9s 627ms/step - loss: 0.3319 - categorical_accuracy: 0.8933 - val_loss: 1.0146 - val_categorical_accuracy: 0.6500
# Epoch 25/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.3240 - categorical_accuracy: 0.8929WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 9s 620ms/step - loss: 0.3172 - categorical_accuracy: 0.8967 - val_loss: 0.9638 - val_categorical_accuracy: 0.6667
# Epoch 26/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2893 - categorical_accuracy: 0.9036WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 9s 613ms/step - loss: 0.3076 - categorical_accuracy: 0.8900 - val_loss: 0.9988 - val_categorical_accuracy: 0.6583
# Epoch 27/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.3176 - categorical_accuracy: 0.8821WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 633ms/step - loss: 0.3116 - categorical_accuracy: 0.8867 - val_loss: 1.0189 - val_categorical_accuracy: 0.6583
# Epoch 28/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.3094 - categorical_accuracy: 0.8750WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 640ms/step - loss: 0.3040 - categorical_accuracy: 0.8800 - val_loss: 0.9936 - val_categorical_accuracy: 0.6667
# Epoch 29/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2655 - categorical_accuracy: 0.9143WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 9s 627ms/step - loss: 0.2816 - categorical_accuracy: 0.9133 - val_loss: 1.0494 - val_categorical_accuracy: 0.6583
# Epoch 30/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.3040 - categorical_accuracy: 0.8857WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 9s 613ms/step - loss: 0.2993 - categorical_accuracy: 0.8900 - val_loss: 1.0053 - val_categorical_accuracy: 0.6750
# Epoch 31/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2724 - categorical_accuracy: 0.9071WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 9s 627ms/step - loss: 0.2826 - categorical_accuracy: 0.9033 - val_loss: 1.0049 - val_categorical_accuracy: 0.6667
# Epoch 32/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2734 - categorical_accuracy: 0.9107WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 9s 613ms/step - loss: 0.2789 - categorical_accuracy: 0.9067 - val_loss: 1.0075 - val_categorical_accuracy: 0.6750
# Epoch 33/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2653 - categorical_accuracy: 0.9214WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 9s 613ms/step - loss: 0.2672 - categorical_accuracy: 0.9167 - val_loss: 1.0511 - val_categorical_accuracy: 0.6583
# Epoch 34/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2618 - categorical_accuracy: 0.9143WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 9s 633ms/step - loss: 0.2710 - categorical_accuracy: 0.9067 - val_loss: 1.0182 - val_categorical_accuracy: 0.6583
# Epoch 35/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2649 - categorical_accuracy: 0.9179WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 9s 633ms/step - loss: 0.2591 - categorical_accuracy: 0.9200 - val_loss: 1.0270 - val_categorical_accuracy: 0.6667
# Epoch 36/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2581 - categorical_accuracy: 0.9179WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 9s 613ms/step - loss: 0.2548 - categorical_accuracy: 0.9133 - val_loss: 1.0613 - val_categorical_accuracy: 0.6500
# Epoch 37/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2545 - categorical_accuracy: 0.9143WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 9s 627ms/step - loss: 0.2574 - categorical_accuracy: 0.9100 - val_loss: 1.0408 - val_categorical_accuracy: 0.6583
# Epoch 38/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2642 - categorical_accuracy: 0.9107WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 9s 613ms/step - loss: 0.2566 - categorical_accuracy: 0.9133 - val_loss: 1.0405 - val_categorical_accuracy: 0.6667
# Epoch 39/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2447 - categorical_accuracy: 0.9250WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 9s 606ms/step - loss: 0.2447 - categorical_accuracy: 0.9267 - val_loss: 1.0553 - val_categorical_accuracy: 0.6667
# Epoch 40/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2542 - categorical_accuracy: 0.9107WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 9s 613ms/step - loss: 0.2530 - categorical_accuracy: 0.9100 - val_loss: 1.0554 - val_categorical_accuracy: 0.6500
# Epoch 41/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2347 - categorical_accuracy: 0.9250WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 9s 613ms/step - loss: 0.2436 - categorical_accuracy: 0.9233 - val_loss: 1.0776 - val_categorical_accuracy: 0.6583
# Epoch 42/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2500 - categorical_accuracy: 0.9143WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 9s 627ms/step - loss: 0.2439 - categorical_accuracy: 0.9133 - val_loss: 1.0900 - val_categorical_accuracy: 0.6583
# Epoch 43/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2283 - categorical_accuracy: 0.9357WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 9s 613ms/step - loss: 0.2334 - categorical_accuracy: 0.9300 - val_loss: 1.0684 - val_categorical_accuracy: 0.6667
# Epoch 44/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2406 - categorical_accuracy: 0.9321WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 9s 607ms/step - loss: 0.2349 - categorical_accuracy: 0.9300 - val_loss: 1.0944 - val_categorical_accuracy: 0.6583
# Epoch 45/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2351 - categorical_accuracy: 0.9321WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 9s 613ms/step - loss: 0.2331 - categorical_accuracy: 0.9333 - val_loss: 1.0803 - val_categorical_accuracy: 0.6667
# Epoch 46/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2382 - categorical_accuracy: 0.9179WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 9s 611ms/step - loss: 0.2395 - categorical_accuracy: 0.9200 - val_loss: 1.0963 - val_categorical_accuracy: 0.6417
# Epoch 47/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2345 - categorical_accuracy: 0.9214WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 9s 609ms/step - loss: 0.2328 - categorical_accuracy: 0.9233 - val_loss: 1.1186 - val_categorical_accuracy: 0.6417
# Epoch 48/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2298 - categorical_accuracy: 0.9286WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 9s 613ms/step - loss: 0.2271 - categorical_accuracy: 0.9300 - val_loss: 1.0940 - val_categorical_accuracy: 0.6583
# Epoch 49/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2257 - categorical_accuracy: 0.9429WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 9s 620ms/step - loss: 0.2229 - categorical_accuracy: 0.9433 - val_loss: 1.0942 - val_categorical_accuracy: 0.6750
# Epoch 50/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.2169 - categorical_accuracy: 0.9500WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 9s 620ms/step - loss: 0.2149 - categorical_accuracy: 0.9533 - val_loss: 1.1060 - val_categorical_accuracy: 0.6667

# %%
history.history

# %% [markdown]
# #### Plot the learning curves

# %%
# Run this cell to plot accuracy vs epoch and loss vs epoch

plt.figure(figsize=(15,5))
plt.subplot(121)
try:
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
except KeyError:
    try:
        plt.plot(history.history['acc'])
        plt.plot(history.history['val_acc'])
    except KeyError:
        plt.plot(history.history['categorical_accuracy'])
        plt.plot(history.history['val_categorical_accuracy'])
plt.title('Accuracy vs. epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='lower right')

plt.subplot(122)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-ad635e69fbe7> in <module>
#       4 plt.subplot(121)
#       5 try:
# ----> 6     plt.plot(history.history['accuracy'])
#       7     plt.plot(history.history['val_accuracy'])
#       8 except KeyError:
#
# TypeError: 'History' object is not subscriptable

# %% [markdown]
# You may notice overfitting in the above plots, through a growing discrepancy between the training and validation loss and accuracy. We will aim to mitigate this using data augmentation. Given our limited dataset, we may be able to improve the performance by applying random modifications to the images in the training data, effectively increasing the size of the dataset.

# %% [markdown]
# #### Create a new data generator with data augmentation
#
# You should now write a function to create a new `ImageDataGenerator` object, which performs the following data preprocessing and augmentation:
#
# * Scales the image pixel values by a factor of 1/255.
# * Randomly rotates images by up to 30 degrees
# * Randomly alters the brightness (picks a brightness shift value) from the range (0.5, 1.5)
# * Randomly flips images horizontally
#
# Hint: you may need to refer to the [documentation](https://keras.io/preprocessing/image/#imagedatagenerator-class) for the `ImageDataGenerator`.

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def get_ImageDataGenerator_augmented():
    """
    This function should return an instance of the ImageDataGenerator class 
    with the above specifications.
    """
    image_gen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=30,
        brightness_range=[0.5,1.5],
        horizontal_flip=True)
    return image_gen

# %%
# Call the function to get an ImageDataGenerator as specified

image_gen_aug = get_ImageDataGenerator_augmented()

# %%
# Run this cell to define training and validation generators 

valid_generator_aug = get_generator(image_gen_aug, valid_dir)
train_generator_aug = get_generator(image_gen_aug, train_dir, seed=10)
# Out:
# Found 120 images belonging to 3 classes.
# Found 300 images belonging to 3 classes.

# %%
# Reset the original train_generator with the same random seed

train_generator = get_generator(image_gen, train_dir, seed=10)
# Out:
# Found 300 images belonging to 3 classes.

# %% [markdown]
# #### Display sample augmented images and labels from the training set
#
# The following cell depends on your function `get_generator` to be implemented correctly. If it raises an error, go back and check the function specifications carefully.
#
# The cell will display augmented and non-augmented images (and labels) from the training dataset, using the `train_generator_aug` and `train_generator` objects defined above (if the images do not correspond to each other, check you have implemented the `seed` argument correctly).

# %%
# Display a few images and labels from the non-augmented and augmented generators

batch = next(train_generator)
batch_images = np.array(batch[0])
batch_labels = np.array(batch[1])

aug_batch = next(train_generator_aug)
aug_batch_images = np.array(aug_batch[0])
aug_batch_labels = np.array(aug_batch[1])

plt.figure(figsize=(16,5))
plt.suptitle("Unaugmented images", fontsize=16)
for n, i in enumerate(np.arange(10)):
    ax = plt.subplot(2, 5, n+1)
    plt.imshow(batch_images[i])
    plt.title(lsun_classes[np.where(batch_labels[i] == 1.)[0][0]])
    plt.axis('off')
plt.figure(figsize=(16,5))
plt.suptitle("Augmented images", fontsize=16)
for n, i in enumerate(np.arange(10)):
    ax = plt.subplot(2, 5, n+1)
    plt.imshow(aug_batch_images[i])
    plt.title(lsun_classes[np.where(aug_batch_labels[i] == 1.)[0][0]])
    plt.axis('off')

# %%
# Reset the augmented data generator

train_generator_aug = get_generator(image_gen_aug, train_dir)
# Out:
# Found 300 images belonging to 3 classes.

# %% [markdown]
# #### Train a new model on the augmented dataset

# %%
# Build and compile a new model

lsun_new_model = get_model((64, 64, 3))

# %%
# Train the model

history_augmented = train_model(lsun_new_model, train_generator_aug, valid_generator_aug, epochs=50)
# Out:
# Train for 15 steps, validate for 6 steps
# Epoch 1/50
# 14/15 [===========================>..] - ETA: 0s - loss: 1.0852 - categorical_accuracy: 0.3786WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 16s 1s/step - loss: 1.0831 - categorical_accuracy: 0.3867 - val_loss: 1.0534 - val_categorical_accuracy: 0.5917
# Epoch 2/50
# 14/15 [===========================>..] - ETA: 0s - loss: 1.0345 - categorical_accuracy: 0.4786WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 660ms/step - loss: 1.0314 - categorical_accuracy: 0.4800 - val_loss: 0.9978 - val_categorical_accuracy: 0.5417
# Epoch 3/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.9514 - categorical_accuracy: 0.5643WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 673ms/step - loss: 0.9432 - categorical_accuracy: 0.5733 - val_loss: 0.9749 - val_categorical_accuracy: 0.4917
# Epoch 4/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.9204 - categorical_accuracy: 0.5750WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 666ms/step - loss: 0.9226 - categorical_accuracy: 0.5700 - val_loss: 0.8735 - val_categorical_accuracy: 0.6083
# Epoch 5/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8627 - categorical_accuracy: 0.6143WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 673ms/step - loss: 0.8596 - categorical_accuracy: 0.6167 - val_loss: 0.8335 - val_categorical_accuracy: 0.6333
# Epoch 6/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.7853 - categorical_accuracy: 0.6857WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 680ms/step - loss: 0.7879 - categorical_accuracy: 0.6800 - val_loss: 0.8171 - val_categorical_accuracy: 0.5917
# Epoch 7/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8129 - categorical_accuracy: 0.6464WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 687ms/step - loss: 0.8150 - categorical_accuracy: 0.6367 - val_loss: 0.8562 - val_categorical_accuracy: 0.5917
# Epoch 8/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8125 - categorical_accuracy: 0.6357WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 673ms/step - loss: 0.8118 - categorical_accuracy: 0.6367 - val_loss: 0.7839 - val_categorical_accuracy: 0.6000
# Epoch 9/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.7482 - categorical_accuracy: 0.6464WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 660ms/step - loss: 0.7564 - categorical_accuracy: 0.6433 - val_loss: 0.7541 - val_categorical_accuracy: 0.6750
# Epoch 10/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.7928 - categorical_accuracy: 0.6357WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 653ms/step - loss: 0.7812 - categorical_accuracy: 0.6467 - val_loss: 0.7481 - val_categorical_accuracy: 0.6833
# Epoch 11/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.7303 - categorical_accuracy: 0.6821WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 647ms/step - loss: 0.7285 - categorical_accuracy: 0.6833 - val_loss: 0.8869 - val_categorical_accuracy: 0.6000
# Epoch 12/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.8041 - categorical_accuracy: 0.6357WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 667ms/step - loss: 0.8007 - categorical_accuracy: 0.6333 - val_loss: 0.7764 - val_categorical_accuracy: 0.6667
# Epoch 13/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.7698 - categorical_accuracy: 0.6571WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 667ms/step - loss: 0.7595 - categorical_accuracy: 0.6633 - val_loss: 0.7926 - val_categorical_accuracy: 0.6333
# Epoch 14/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.7116 - categorical_accuracy: 0.6821WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 667ms/step - loss: 0.7255 - categorical_accuracy: 0.6767 - val_loss: 0.7306 - val_categorical_accuracy: 0.6750
# Epoch 15/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.7347 - categorical_accuracy: 0.6607WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 667ms/step - loss: 0.7363 - categorical_accuracy: 0.6667 - val_loss: 0.7416 - val_categorical_accuracy: 0.6500
# Epoch 16/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6919 - categorical_accuracy: 0.7143WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 660ms/step - loss: 0.6903 - categorical_accuracy: 0.7100 - val_loss: 0.7887 - val_categorical_accuracy: 0.6583
# Epoch 17/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.7137 - categorical_accuracy: 0.6857WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 673ms/step - loss: 0.7074 - categorical_accuracy: 0.6900 - val_loss: 0.8055 - val_categorical_accuracy: 0.6333
# Epoch 18/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6934 - categorical_accuracy: 0.7179WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 660ms/step - loss: 0.7008 - categorical_accuracy: 0.7133 - val_loss: 0.8754 - val_categorical_accuracy: 0.6250
# Epoch 19/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.7066 - categorical_accuracy: 0.7179WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 667ms/step - loss: 0.7108 - categorical_accuracy: 0.7267 - val_loss: 0.7229 - val_categorical_accuracy: 0.6333
# Epoch 20/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6542 - categorical_accuracy: 0.7214WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 673ms/step - loss: 0.6574 - categorical_accuracy: 0.7167 - val_loss: 0.7289 - val_categorical_accuracy: 0.6583
# Epoch 21/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6530 - categorical_accuracy: 0.7143WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 700ms/step - loss: 0.6637 - categorical_accuracy: 0.7133 - val_loss: 0.7893 - val_categorical_accuracy: 0.6583
# Epoch 22/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6603 - categorical_accuracy: 0.7393WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 11s 733ms/step - loss: 0.6654 - categorical_accuracy: 0.7367 - val_loss: 0.8992 - val_categorical_accuracy: 0.6333
# Epoch 23/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6760 - categorical_accuracy: 0.6929WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 660ms/step - loss: 0.6755 - categorical_accuracy: 0.6967 - val_loss: 0.8301 - val_categorical_accuracy: 0.6333
# Epoch 24/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6797 - categorical_accuracy: 0.6964WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 660ms/step - loss: 0.6676 - categorical_accuracy: 0.7033 - val_loss: 0.8092 - val_categorical_accuracy: 0.6167
# Epoch 25/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6849 - categorical_accuracy: 0.6893WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 673ms/step - loss: 0.7087 - categorical_accuracy: 0.6833 - val_loss: 0.7443 - val_categorical_accuracy: 0.6583
# Epoch 26/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6209 - categorical_accuracy: 0.7643WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 693ms/step - loss: 0.6339 - categorical_accuracy: 0.7567 - val_loss: 0.7364 - val_categorical_accuracy: 0.6750
# Epoch 27/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6111 - categorical_accuracy: 0.7393WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 11s 720ms/step - loss: 0.6150 - categorical_accuracy: 0.7333 - val_loss: 0.7435 - val_categorical_accuracy: 0.6417
# Epoch 28/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6441 - categorical_accuracy: 0.7357WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 667ms/step - loss: 0.6302 - categorical_accuracy: 0.7467 - val_loss: 0.7629 - val_categorical_accuracy: 0.6250
# Epoch 29/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6093 - categorical_accuracy: 0.7571WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 673ms/step - loss: 0.6026 - categorical_accuracy: 0.7567 - val_loss: 0.7260 - val_categorical_accuracy: 0.6750
# Epoch 30/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6034 - categorical_accuracy: 0.7357WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 653ms/step - loss: 0.6135 - categorical_accuracy: 0.7267 - val_loss: 0.6766 - val_categorical_accuracy: 0.6667
# Epoch 31/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5624 - categorical_accuracy: 0.7643WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 673ms/step - loss: 0.5660 - categorical_accuracy: 0.7600 - val_loss: 0.7354 - val_categorical_accuracy: 0.6750
# Epoch 32/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5928 - categorical_accuracy: 0.7643WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 667ms/step - loss: 0.5886 - categorical_accuracy: 0.7733 - val_loss: 0.6911 - val_categorical_accuracy: 0.6750
# Epoch 33/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5892 - categorical_accuracy: 0.7357WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 660ms/step - loss: 0.5819 - categorical_accuracy: 0.7433 - val_loss: 0.7194 - val_categorical_accuracy: 0.6583
# Epoch 34/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5753 - categorical_accuracy: 0.7750WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 667ms/step - loss: 0.5747 - categorical_accuracy: 0.7733 - val_loss: 0.7407 - val_categorical_accuracy: 0.6500
# Epoch 35/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5768 - categorical_accuracy: 0.7857WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 660ms/step - loss: 0.5793 - categorical_accuracy: 0.7833 - val_loss: 0.7468 - val_categorical_accuracy: 0.7250
# Epoch 36/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5649 - categorical_accuracy: 0.7750WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 667ms/step - loss: 0.5619 - categorical_accuracy: 0.7700 - val_loss: 0.7400 - val_categorical_accuracy: 0.6750
# Epoch 37/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.6002 - categorical_accuracy: 0.7714WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 660ms/step - loss: 0.5874 - categorical_accuracy: 0.7767 - val_loss: 0.7350 - val_categorical_accuracy: 0.6750
# Epoch 38/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5763 - categorical_accuracy: 0.7607WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 647ms/step - loss: 0.5888 - categorical_accuracy: 0.7567 - val_loss: 0.7221 - val_categorical_accuracy: 0.6583
# Epoch 39/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5822 - categorical_accuracy: 0.7750WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 660ms/step - loss: 0.5719 - categorical_accuracy: 0.7767 - val_loss: 0.7193 - val_categorical_accuracy: 0.6667
# Epoch 40/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5658 - categorical_accuracy: 0.7500WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 680ms/step - loss: 0.5533 - categorical_accuracy: 0.7567 - val_loss: 0.6975 - val_categorical_accuracy: 0.6667
# Epoch 41/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5621 - categorical_accuracy: 0.7607WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 673ms/step - loss: 0.5587 - categorical_accuracy: 0.7633 - val_loss: 0.7225 - val_categorical_accuracy: 0.6833
# Epoch 42/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5550 - categorical_accuracy: 0.7786WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 680ms/step - loss: 0.5566 - categorical_accuracy: 0.7767 - val_loss: 0.7071 - val_categorical_accuracy: 0.6583
# Epoch 43/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5490 - categorical_accuracy: 0.7679WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 673ms/step - loss: 0.5570 - categorical_accuracy: 0.7667 - val_loss: 0.7583 - val_categorical_accuracy: 0.6250
# Epoch 44/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5137 - categorical_accuracy: 0.7893WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 673ms/step - loss: 0.5221 - categorical_accuracy: 0.7867 - val_loss: 0.7214 - val_categorical_accuracy: 0.6333
# Epoch 45/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5618 - categorical_accuracy: 0.7500WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 667ms/step - loss: 0.5471 - categorical_accuracy: 0.7600 - val_loss: 0.7143 - val_categorical_accuracy: 0.6500
# Epoch 46/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5592 - categorical_accuracy: 0.7679WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 667ms/step - loss: 0.5659 - categorical_accuracy: 0.7700 - val_loss: 0.7126 - val_categorical_accuracy: 0.6750
# Epoch 47/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5486 - categorical_accuracy: 0.7857WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 660ms/step - loss: 0.5391 - categorical_accuracy: 0.7900 - val_loss: 0.7750 - val_categorical_accuracy: 0.6250
# Epoch 48/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5426 - categorical_accuracy: 0.8000WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 660ms/step - loss: 0.5478 - categorical_accuracy: 0.8000 - val_loss: 0.6821 - val_categorical_accuracy: 0.6583
# Epoch 49/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5667 - categorical_accuracy: 0.7643WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 660ms/step - loss: 0.5557 - categorical_accuracy: 0.7733 - val_loss: 0.7272 - val_categorical_accuracy: 0.6833
# Epoch 50/50
# 14/15 [===========================>..] - ETA: 0s - loss: 0.5176 - categorical_accuracy: 0.7893WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,categorical_accuracy,val_loss,val_categorical_accuracy
# 15/15 [==============================] - 10s 673ms/step - loss: 0.5169 - categorical_accuracy: 0.7900 - val_loss: 0.7227 - val_categorical_accuracy: 0.6833

# %% [markdown]
# #### Plot the learning curves

# %%
# Run this cell to plot accuracy vs epoch and loss vs epoch

plt.figure(figsize=(15,5))
plt.subplot(121)
try:
    plt.plot(history_augmented.history['accuracy'])
    plt.plot(history_augmented.history['val_accuracy'])
except KeyError:
    try:
        plt.plot(history_augmented.history['acc'])
        plt.plot(history_augmented.history['val_acc'])
    except KeyError:
        plt.plot(history_augmented.history['categorical_accuracy'])
        plt.plot(history_augmented.history['val_categorical_accuracy'])
plt.title('Accuracy vs. epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='lower right')

plt.subplot(122)
plt.plot(history_augmented.history['loss'])
plt.plot(history_augmented.history['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# Do you see an improvement in the overfitting? This will of course vary based on your particular run and whether you have altered the hyperparameters.

# %% [markdown]
# #### Get predictions using the trained model

# %%
# Get model predictions for the first 3 batches of test data

num_batches = 3
seed = 25
test_generator = get_generator(image_gen_aug, test_dir, seed=seed)
predictions = lsun_new_model.predict_generator(test_generator, steps=num_batches)
# Out:
# Found 300 images belonging to 3 classes.

# %%
# Run this cell to view randomly selected images and model predictions

# Get images and ground truth labels
test_generator = get_generator(image_gen_aug, test_dir, seed=seed)
batches = []
for i in range(num_batches):
    batches.append(next(test_generator))
    
batch_images = np.vstack([b[0] for b in batches])
batch_labels = np.concatenate([b[1].astype(np.int32) for b in batches])

# Randomly select images from the batch
inx = np.random.choice(predictions.shape[0], 4, replace=False)
print(inx)

fig, axes = plt.subplots(4, 2, figsize=(16, 12))
fig.subplots_adjust(hspace=0.4, wspace=-0.2)

for n, i in enumerate(inx):
    axes[n, 0].imshow(batch_images[i])
    axes[n, 0].get_xaxis().set_visible(False)
    axes[n, 0].get_yaxis().set_visible(False)
    axes[n, 0].text(30., -3.5, lsun_classes[np.where(batch_labels[i] == 1.)[0][0]], 
                    horizontalalignment='center')
    axes[n, 1].bar(np.arange(len(predictions[i])), predictions[i])
    axes[n, 1].set_xticks(np.arange(len(predictions[i])))
    axes[n, 1].set_xticklabels(lsun_classes)
    axes[n, 1].set_title(f"Categorical distribution. Model prediction: {lsun_classes[np.argmax(predictions[i])]}")
    
plt.show()
# Out:
# Found 300 images belonging to 3 classes.
# [58 10 33  4]

# %% [markdown]
# Congratulations! This completes the first part of the programming assignment using the tf.keras image data processing tools.

# %% [markdown]
# ### Part 2: tf.data
#
# ![CIFAR-100 overview image](data/cifar100/cifar100.png)
#
# #### The CIFAR-100 Dataset

# %% [markdown]
# In the second part of this assignment, you will use the [CIFAR-100 dataset](https://www.cs.toronto.edu/~kriz/cifar.html). This image dataset has 100 classes with 500 training images and 100 test images per class.
#
# * A. Krizhevsky. "Learning Multiple Layers of Features from Tiny Images". April 2009
#
# Your goal is to use the tf.data module preprocessing tools to construct a data ingestion pipeline including filtering and function mapping over the dataset to train a neural network to classify the images.

# %% [markdown]
# #### Load the dataset

# %%
# Load the data, along with the labels

(train_data, train_labels), (test_data, test_labels) = cifar100.load_data(label_mode='fine')
with open('data/cifar100/cifar100_labels.json', 'r') as j:
    cifar_labels = json.load(j)

# %% [markdown]
# #### Display sample images and labels from the training set

# %%
# Display a few images and labels

plt.figure(figsize=(15,8))
inx = np.random.choice(train_data.shape[0], 32, replace=False)
for n, i in enumerate(inx):
    ax = plt.subplot(4, 8, n+1)
    plt.imshow(train_data[i])
    plt.title(cifar_labels[int(train_labels[i])])
    plt.axis('off')

# %% [markdown]
# #### Create Dataset objects for the train and test images
#
# You should now write a function to create a `tf.data.Dataset` object for each of the training and test images and labels. This function should take a numpy array of images in the first argument and a numpy array of labels in the second argument, and create a `Dataset` object.
#
# Your function should then return the `Dataset` object. Do not batch or shuffle the `Dataset` (this will be done later).

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def create_dataset(data, labels):
    """
    This function takes a numpy array batch of images in the first argument, and
    a corresponding array containing the labels in the second argument.
    The function should then create a tf.data.Dataset object with these inputs
    and outputs, and return it.
    """
    dataset = tf.data.Dataset.from_tensor_slices((data, labels))
    return dataset

# %%
# Run the below cell to convert the training and test data and labels into datasets

train_dataset = create_dataset(train_data, train_labels)
test_dataset = create_dataset(test_data, test_labels)

# %%
# Check the element_spec of your datasets

print(train_dataset.element_spec)
print(test_dataset.element_spec)
# Out:
# (TensorSpec(shape=(32, 32, 3), dtype=tf.uint8, name=None), TensorSpec(shape=(1,), dtype=tf.int64, name=None))
# (TensorSpec(shape=(32, 32, 3), dtype=tf.uint8, name=None), TensorSpec(shape=(1,), dtype=tf.int64, name=None))

# %% [markdown]
# #### Filter the Dataset
#
# Write a function to filter the train and test datasets so that they only generate images that belong to a specified set of classes.
#
# The function should take a `Dataset` object in the first argument, and a list of integer class indices in the second argument. Inside your function you should define an auxiliary function that you will use with the `filter` method of the `Dataset` object. This auxiliary function should take image and label arguments (as in the `element_spec`) for a single element in the batch, and return a boolean indicating if the label is one of the allowed classes.
#
# Your function should then return the filtered dataset.
#
# **Hint:** you may need to use the [`tf.equal`](https://www.tensorflow.org/api_docs/python/tf/math/equal), [`tf.cast`](https://www.tensorflow.org/api_docs/python/tf/dtypes/cast) and [`tf.math.reduce_any`](https://www.tensorflow.org/api_docs/python/tf/math/reduce_any) functions in your auxiliary function.

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def filter_classes(dataset, classes):
    """
    This function should filter the dataset by only retaining dataset elements whose
    label belongs to one of the integers in the classes list.
    The function should then return the filtered Dataset object.
    """
    def auxiliary(image, label):
        return tf.math.reduce_any(tf.equal(tf.cast(label, classes.dtype), classes))
    classes = tf.constant(classes, dtype=tf.uint8)
    return dataset.filter(auxiliary)

# %%
# Run the below cell to filter the datasets using your function

cifar_classes = [0, 29, 99] # Your datasets should contain only classes in this list

train_dataset = filter_classes(train_dataset, cifar_classes)
test_dataset = filter_classes(test_dataset, cifar_classes)

# %%
train_dataset
# Out:
# <FilterDataset shapes: ((32, 32, 3), (1,)), types: (tf.uint8, tf.int64)>

# %% [markdown]
# #### Apply map functions to the Dataset
#
# You should now write two functions that use the `map` method to process the images and labels in the filtered dataset.
#
# The first function should one-hot encode the remaining labels so that we can train the network using a categorical cross entropy loss.
#
# The function should take a `Dataset` object as an argument. Inside your function you should define an auxiliary function that you will use with the `map` method of the `Dataset` object. This auxiliary function should take image and label arguments (as in the `element_spec`) for a single element in the batch, and return a tuple of two elements, with the unmodified image in the first element, and a one-hot vector in the second element. The labels should be encoded according to the following:
#
# * Class 0 maps to `[1., 0., 0.]`
# * Class 29 maps to `[0., 1., 0.]`
# * Class 99 maps to `[0., 0., 1.]`
#
# Your function should then return the mapped dataset.

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def map_labels(dataset):
    """
    This function should map over the dataset to convert the label to a 
    one-hot vector. The encoding should be done according to the above specification.
    The function should then return the mapped Dataset object.
    """
    def auxilary(image, label):
        if label == 0:
            return (image, tf.constant([1., 0., 0.]))
        elif label == 29:
            return (image, tf.constant([0., 1., 0.]))
        else:
            return (image, tf.constant([0., 0., 1.]))
    return dataset.map(auxilary)

# %%
# Run the below cell to one-hot encode the training and test labels.

train_dataset = map_labels(train_dataset)
test_dataset = map_labels(test_dataset)

# %%
train_dataset
# Out:
# <MapDataset shapes: ((32, 32, 3), (3,)), types: (tf.uint8, tf.float32)>

# %% [markdown]
# The second function should process the images according to the following specification:
#
# * Rescale the image pixel values by a factor of 1/255.
# * Convert the colour images (3 channels) to black and white images (single channel) by computing the average pixel value across all channels.
#
# The function should take a `Dataset` object as an argument. Inside your function you should again define an auxiliary function that you will use with the `map` method of the `Dataset` object. This auxiliary function should take image and label arguments (as in the `element_spec`) for a single element in the batch, and return a tuple of two elements, with the processed image in the first element, and the unmodified label in the second argument.
#
# Your function should then return the mapped dataset.
#
# **Hint:** you may find it useful to use [`tf.reduce_mean`](https://www.tensorflow.org/api_docs/python/tf/math/reduce_mean?version=stable) since the black and white image is the colour-average of the colour images. You can also use the `keepdims` keyword in `tf.reduce_mean` to retain the single colour channel.

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def map_images(dataset):
    """
    This function should map over the dataset to process the image according to the 
    above specification. The function should then return the mapped Dataset object.
    """
    def auxillary(image, label):
        image = image/255
        image = tf.reduce_mean(image, axis=2, keepdims=True)
        return image, label
    return dataset.map(auxillary)

# %%
# Run the below cell to apply your mapping function to the datasets

train_dataset_bw = map_images(train_dataset)
test_dataset_bw = map_images(test_dataset)

# %% [markdown]
# #### Display a batch of processed images

# %%
# Run this cell to view a selection of images before and after processing

plt.figure(figsize=(16,5))
plt.suptitle("Unprocessed images", fontsize=16)
for n, elem in enumerate(train_dataset.take(10)):
    images, labels = elem
    ax = plt.subplot(2, 5, n+1)
    plt.title(cifar_labels[cifar_classes[np.where(labels == 1.)[0][0]]])
    plt.imshow(np.squeeze(images), cmap='gray')
    plt.axis('off')
    
plt.figure(figsize=(16,5))
plt.suptitle("Processed images", fontsize=16)
for n, elem in enumerate(train_dataset_bw.take(10)):
    images_bw, labels_bw = elem
    ax = plt.subplot(2, 5, n+1)
    plt.title(cifar_labels[cifar_classes[np.where(labels_bw == 1.)[0][0]]])
    plt.imshow(np.squeeze(images_bw), cmap='gray')
    plt.axis('off')

# %% [markdown]
# We will now batch and shuffle the Dataset objects.

# %%
# Run the below cell to batch the training dataset and expand the final dimensinos

train_dataset_bw = train_dataset_bw.batch(10)
train_dataset_bw = train_dataset_bw.shuffle(100)

test_dataset_bw = test_dataset_bw.batch(10)
test_dataset_bw = test_dataset_bw.shuffle(100)

# %% [markdown]
# #### Train a neural network model
#
# Now we will train a model using the `Dataset` objects. We will use the model specification and function from the first part of this assignment, only modifying the size of the input images.

# %%
# Build and compile a new model with our original spec, using the new image size
    
cifar_model = get_model((32, 32, 1))

# %%
# Train the model for 15 epochs

history = cifar_model.fit(train_dataset_bw, validation_data=test_dataset_bw, epochs=15)
# Out:
# Epoch 1/15
# 150/150 [==============================] - 20s 133ms/step - loss: 1.0731 - categorical_accuracy: 0.3740 - val_loss: 0.0000e+00 - val_categorical_accuracy: 0.0000e+00
# Epoch 2/15
# 150/150 [==============================] - 18s 121ms/step - loss: 0.9249 - categorical_accuracy: 0.5820 - val_loss: 0.7694 - val_categorical_accuracy: 0.6800
# Epoch 3/15
# 150/150 [==============================] - 18s 123ms/step - loss: 0.7740 - categorical_accuracy: 0.6833 - val_loss: 0.7107 - val_categorical_accuracy: 0.7200
# Epoch 4/15
# 150/150 [==============================] - 18s 119ms/step - loss: 0.6938 - categorical_accuracy: 0.7187 - val_loss: 0.6824 - val_categorical_accuracy: 0.7367
# Epoch 5/15
# 150/150 [==============================] - 18s 118ms/step - loss: 0.6470 - categorical_accuracy: 0.7440 - val_loss: 0.6373 - val_categorical_accuracy: 0.7600
# Epoch 6/15
# 150/150 [==============================] - 18s 118ms/step - loss: 0.6114 - categorical_accuracy: 0.7547 - val_loss: 0.6494 - val_categorical_accuracy: 0.7400
# Epoch 7/15
# 150/150 [==============================] - 18s 123ms/step - loss: 0.5811 - categorical_accuracy: 0.7607 - val_loss: 0.6304 - val_categorical_accuracy: 0.7467
# Epoch 8/15
# 150/150 [==============================] - 22s 145ms/step - loss: 0.5622 - categorical_accuracy: 0.7787 - val_loss: 0.5983 - val_categorical_accuracy: 0.7700
# Epoch 9/15
# 150/150 [==============================] - 18s 120ms/step - loss: 0.5339 - categorical_accuracy: 0.7920 - val_loss: 0.5984 - val_categorical_accuracy: 0.7533
# Epoch 10/15
# 150/150 [==============================] - 19s 127ms/step - loss: 0.5152 - categorical_accuracy: 0.7913 - val_loss: 0.5864 - val_categorical_accuracy: 0.7733
# Epoch 11/15
# 150/150 [==============================] - 19s 127ms/step - loss: 0.5080 - categorical_accuracy: 0.8120 - val_loss: 0.5809 - val_categorical_accuracy: 0.7600
# Epoch 12/15
# 150/150 [==============================] - 19s 128ms/step - loss: 0.4800 - categorical_accuracy: 0.8140 - val_loss: 0.5842 - val_categorical_accuracy: 0.7733
# Epoch 13/15
# 150/150 [==============================] - 19s 128ms/step - loss: 0.4583 - categorical_accuracy: 0.8213 - val_loss: 0.6290 - val_categorical_accuracy: 0.7233
# Epoch 14/15
# 29/30 [============================>.] - ETA: 0s - loss: 0.4367 - categorical_accuracy: 0.8448

# %% [markdown]
# #### Plot the learning curves

# %%
# Run this cell to plot accuracy vs epoch and loss vs epoch

plt.figure(figsize=(15,5))
plt.subplot(121)
try:
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
except KeyError:
    try:
        plt.plot(history.history['acc'])
        plt.plot(history.history['val_acc'])
    except KeyError:
        plt.plot(history.history['categorical_accuracy'])
        plt.plot(history.history['val_categorical_accuracy'])
plt.title('Accuracy vs. epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='lower right')

plt.subplot(122)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %%
# Create an iterable from the batched test dataset

test_dataset = test_dataset.batch(10)
iter_test_dataset = iter(test_dataset)

# %%
# Display model predictions for a sample of test images

plt.figure(figsize=(15,8))
inx = np.random.choice(test_data.shape[0], 18, replace=False)
images, labels = next(iter_test_dataset)
probs = cifar_model(tf.reduce_mean(tf.cast(images, tf.float32), axis=-1, keepdims=True) / 255.)
preds = np.argmax(probs, axis=1)
for n in range(10):
    ax = plt.subplot(2, 5, n+1)
    plt.imshow(images[n])
    plt.title(cifar_labels[cifar_classes[np.where(labels[n].numpy() == 1.0)[0][0]]])
    plt.text(0, 35, "Model prediction: {}".format(cifar_labels[cifar_classes[preds[n]]]))
    plt.axis('off')

# %% [markdown]
# Congratulations for completing this programming assignment! In the next week of the course we will learn to develop models for sequential data.
