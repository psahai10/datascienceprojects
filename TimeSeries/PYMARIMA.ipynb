# %%
import pmdarima as pm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['figure.dpi']=400
from statsmodels.tsa.stattools import adfuller

# %%
Y = [[1111.61158726],
       [-982.42332906],
       [-134.66808823],
       [-205.14154532],
       [ 177.89552646],
       [ 820.05691126],
       [-470.15801278],
       [1111.60833949],
       [-982.20385525],
       [-133.7248581 ],
       [-204.46230939],
       [ 178.1486971 ],
       [ 821.71275914],
       [-469.98472214],
       [1112.16022787],
       [-980.64432308],
       [-132.92411751],
       [-205.77167756],
       [ 177.66920794],
       [ 820.76887743],
       [-471.47784752],
       [1111.3741436 ],
       [-981.48158238],
       [-132.74401305],
       [-204.53633439],
       [ 179.07780795],
       [ 818.8631347 ],
       [-470.83259398],
       [1109.3718552 ],
       [-982.53644557],
       [-134.43293538],
       [-204.68383755],
       [ 178.21989747],
       [ 821.40472357],
       [-469.99089267]]
Y = [x.pop() for x in Y]
dates = pd.date_range(start ='2013-01-01',  
         end ='2013-02-04', freq ='1D')
dic = {'dates':dates, 'Y':Y}
df1 = pd.DataFrame(dic)
df1.set_index('dates', inplace=True)
df1.head()
# Out:
#                       Y
# dates
# 2013-01-01  1111.611587
# 2013-01-02  -982.423329
# 2013-01-03  -134.668088
# 2013-01-04  -205.141545
# 2013-01-05   177.895526

# %%
# Create auto_arima model
model1 = pm.auto_arima(df1,
                      seasonal=True, m=7,
                      d=0, D=1, 
                 	  max_p=2, max_q=2,
                      trace=True,
                      error_action='ignore',
                      suppress_warnings=True)
                       
# Print model summary
print(model1.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,1,1)[7] intercept   : AIC=inf, Time=0.56 sec
#  ARIMA(0,0,0)(0,1,0)[7] intercept   : AIC=91.630, Time=0.00 sec
#  ARIMA(1,0,0)(1,1,0)[7] intercept   : AIC=91.508, Time=0.07 sec
#  ARIMA(0,0,1)(0,1,1)[7] intercept   : AIC=inf, Time=0.23 sec
#  ARIMA(0,0,0)(0,1,0)[7]             : AIC=89.631, Time=0.02 sec
#  ARIMA(0,0,0)(1,1,0)[7] intercept   : AIC=91.596, Time=0.05 sec
#  ARIMA(0,0,0)(0,1,1)[7] intercept   : AIC=inf, Time=0.28 sec
#  ARIMA(0,0,0)(1,1,1)[7] intercept   : AIC=inf, Time=0.27 sec
#  ARIMA(1,0,0)(0,1,0)[7] intercept   : AIC=92.332, Time=0.02 sec
#  ARIMA(0,0,1)(0,1,0)[7] intercept   : AIC=92.763, Time=0.04 sec
#  ARIMA(1,0,1)(0,1,0)[7] intercept   : AIC=93.838, Time=0.04 sec
#
# Best model:  ARIMA(0,0,0)(0,1,0)[7]
# Total fit time: 1.567 seconds
#                                 SARIMAX Results
# ===============================================================================
# Dep. Variable:                       y   No. Observations:                   35
# Model:             SARIMAX(0, 1, 0, 7)   Log Likelihood                 -43.816
# Date:                 Thu, 15 Oct 2020   AIC                             89.631
# Time:                         16:10:20   BIC                             90.964
# Sample:                              0   HQIC                            90.039
#                                   - 35
# Covariance Type:                   opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         1.3388      0.454      2.946      0.003       0.448       2.229
# ===================================================================================
# Ljung-Box (Q):                       28.22   Jarque-Bera (JB):                 0.69
# Prob(Q):                              0.40   Prob(JB):                         0.71
# Heteroskedasticity (H):               2.86   Skew:                             0.05
# Prob(H) (two-sided):                  0.13   Kurtosis:                         2.24
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
Y =[[ 2.87034704e+02],
       [ 1.10595682e+02],
       [ 3.05703744e+02],
       [ 3.22875181e+02],
       [ 5.81451700e+02],
       [ 3.23903924e+02],
       [ 3.22647992e+02],
       [ 3.05568525e+01],
       [ 5.82609281e+02],
       [-1.36680337e+00],
       [ 2.35770012e+02],
       [-6.30559364e+02],
       [-6.84567923e+02],
       [-6.15121232e+02],
       [-4.38596382e+02],
       [-8.56957053e+01],
       [ 1.10080242e+02],
       [-1.47193863e+02],
       [ 1.59412258e+02],
       [ 1.36461389e+02],
       [-8.51326486e+01],
       [-1.61150702e+02],
       [-2.94181468e+02],
       [ 1.24392172e+02],
       [ 3.71712683e+00],
       [ 2.80668505e+02],
       [ 3.81999451e+02],
       [ 8.86184040e+02],
       [ 1.00565069e+03],
       [ 1.17104297e+03],
       [ 1.43239792e+03],
       [ 1.14019174e+03],
       [ 1.14024519e+03],
       [ 1.54841286e+03],
       [ 1.45313085e+03],
       [ 1.30053786e+03],
       [ 9.18183289e+02],
       [ 1.41651387e+03],
       [ 1.15311490e+03],
       [ 1.38503575e+03],
       [ 1.82242616e+03],
       [ 1.74274263e+03],
       [ 1.76173756e+03],
       [ 2.22815755e+03],
       [ 2.27867357e+03],
       [ 2.17575834e+03],
       [ 2.40693671e+03],
       [ 2.15199246e+03],
       [ 2.39836829e+03],
       [ 2.27704551e+03],
       [ 2.27949689e+03],
       [ 2.22652086e+03],
       [ 2.04737764e+03],
       [ 1.93454909e+03],
       [ 2.00130873e+03],
       [ 1.84458203e+03],
       [ 1.95851808e+03],
       [ 2.12796955e+03],
       [ 2.08489571e+03],
       [ 1.56798576e+03],
       [ 2.01337818e+03],
       [ 1.66517407e+03],
       [ 2.13197944e+03],
       [ 2.40835478e+03],
       [ 2.54630049e+03],
       [ 2.53512508e+03],
       [ 2.13493493e+03],
       [ 2.57043572e+03],
       [ 2.40603532e+03],
       [ 2.74453595e+03],
       [ 1.99570318e+03],
       [ 2.34921432e+03],
       [ 2.28167361e+03],
       [ 1.96604091e+03],
       [ 2.15418739e+03],
       [ 2.49234544e+03],
       [ 2.61731943e+03],
       [ 2.54374493e+03],
       [ 2.83281223e+03],
       [ 3.29311813e+03],
       [ 2.96959047e+03],
       [ 2.98873454e+03],
       [ 2.65261008e+03],
       [ 2.89052113e+03],
       [ 3.19669889e+03],
       [ 3.11954997e+03],
       [ 3.17475237e+03],
       [ 3.05785572e+03],
       [ 3.48312530e+03],
       [ 3.59255165e+03],
       [ 3.57133829e+03],
       [ 4.03093201e+03],
       [ 4.07930457e+03],
       [ 4.19377895e+03],
       [ 3.41334294e+03],
       [ 3.99150387e+03],
       [ 4.38660015e+03],
       [ 4.29495462e+03],
       [ 4.84812689e+03],
       [ 4.79938999e+03]]
Y = [x.pop() for x in Y]
dates = pd.date_range(start ='2013-01-01',  
         end ='2013-04-10', freq ='1D')
dic = {'dates':dates, 'Y':Y}
df2 = pd.DataFrame(dic)
df2.set_index('dates', inplace=True)
df2.head()
# Out:
#                      Y
# dates
# 2013-01-01  287.034704
# 2013-01-02  110.595682
# 2013-01-03  305.703744
# 2013-01-04  322.875181
# 2013-01-05  581.451700

# %%
# Create model
model2 = pm.auto_arima(df2,
                      seasonal=False, 
                      d=1, 
                      trend='c',
                 	  max_p=2, max_q=2,
                      trace=True,
                      error_action='ignore',
                      suppress_warnings=True) 

# Print model summary
print(model2.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=1410.581, Time=0.25 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1415.630, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1404.869, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1406.232, Time=0.10 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1415.630, Time=0.02 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=1406.822, Time=0.05 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1406.852, Time=0.06 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=1404.869, Time=0.02 sec
#
# Best model:  ARIMA(1,1,0)(0,0,0)[0] intercept
# Total fit time: 0.707 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  100
# Model:               SARIMAX(1, 1, 0)   Log Likelihood                -699.435
# Date:                Thu, 15 Oct 2020   AIC                           1404.869
# Time:                        16:12:40   BIC                           1412.655
# Sample:                             0   HQIC                          1408.019
#                                 - 100
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     64.0503     31.828      2.012      0.044       1.669     126.432
# ar.L1         -0.3479      0.101     -3.431      0.001      -0.547      -0.149
# sigma2      8.048e+04   1.15e+04      6.983      0.000    5.79e+04    1.03e+05
# ===================================================================================
# Ljung-Box (Q):                       31.44   Jarque-Bera (JB):                 4.99
# Prob(Q):                              0.83   Prob(JB):                         0.08
# Heteroskedasticity (H):               1.12   Skew:                            -0.53
# Prob(H) (two-sided):                  0.74   Kurtosis:                         3.28
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
Y=[[  1508.54870006],
       [  -130.93419822],
       [   499.46642567],
       [  1125.07472633],
       [  -221.10135604],
       [ -1368.57110664],
       [ -2437.18800908],
       [ -1891.29558352],
       [ -4006.09003163],
       [ -1749.43075989],
       [ -1105.30649983],
       [ -1172.14890156],
       [   -42.86752764],
       [ -1682.17057168],
       [ -1049.62878769],
       [  -425.50481206],
       [ -1771.96042032],
       [ -2922.00302157],
       [ -3986.90731358],
       [ -3441.53585525],
       [ -5556.85259227],
       [ -3302.6594479 ],
       [ -2655.92204952],
       [ -2721.80796239],
       [ -1595.52501487],
       [ -3233.20372668],
       [ -2603.03377521],
       [ -1977.37676232],
       [ -3325.21901026],
       [ -4472.51590064],
       [ -5540.40928163],
       [ -4993.81685961],
       [ -7107.26914057],
       [ -4852.90028519],
       [ -4205.73870232],
       [ -4274.67877434],
       [ -3146.77227096],
       [ -4785.39746988],
       [ -4155.30992513],
       [ -3529.81619061],
       [ -4877.8475029 ],
       [ -6026.38905765],
       [ -7093.82471596],
       [ -6545.24039287],
       [ -8659.77098878],
       [ -6405.54380038],
       [ -5760.67057521],
       [ -5825.68858338],
       [ -4696.40573398],
       [ -6337.84943616],
       [ -5705.52946542],
       [ -5082.58742723],
       [ -6430.08964398],
       [ -7576.89102749],
       [ -8642.23380385],
       [ -8095.84812694],
       [-10210.07306307],
       [ -7954.48454946],
       [ -7309.49683748],
       [ -7375.26671158]]
Y = [x.pop() for x in Y]
dates = pd.date_range(start ='2013-01-01',  
         end ='2013-03-01', freq ='1D')
dic = {'dates':dates, 'Y':Y}
df3 = pd.DataFrame(dic)
df3.set_index('dates', inplace=True)
df3.head()
# Out:
#                       Y
# dates
# 2013-01-01  1508.548700
# 2013-01-02  -130.934198
# 2013-01-03   499.466426
# 2013-01-04  1125.074726
# 2013-01-05  -221.101356

# %%
# Create model for SARIMAX(p,1,q)(P,1,Q)7
model3 = pm.auto_arima(df3,
                      seasonal=True, m=7,
                      d=1, D=1, 
                      start_p=1, start_q=1,
                      max_p=1, max_q=1,
                      max_P=1, max_Q=1,
                      trace=True,
                      error_action='ignore',
                      suppress_warnings=True) 

# Print model summary
print(model3.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(1,1,1)[7]             : AIC=inf, Time=0.43 sec
#  ARIMA(0,1,0)(0,1,0)[7]             : AIC=921.211, Time=0.02 sec
#  ARIMA(1,1,0)(1,1,0)[7]             : AIC=911.049, Time=0.13 sec
#  ARIMA(0,1,1)(0,1,1)[7]             : AIC=904.675, Time=0.17 sec
#  ARIMA(0,1,1)(0,1,0)[7]             : AIC=923.261, Time=0.03 sec
#  ARIMA(0,1,1)(1,1,1)[7]             : AIC=906.113, Time=0.28 sec
#  ARIMA(0,1,1)(1,1,0)[7]             : AIC=910.465, Time=0.17 sec
#  ARIMA(0,1,0)(0,1,1)[7]             : AIC=904.729, Time=0.11 sec
#  ARIMA(1,1,1)(0,1,1)[7]             : AIC=inf, Time=0.29 sec
#  ARIMA(1,1,0)(0,1,1)[7]             : AIC=904.706, Time=0.18 sec
#  ARIMA(0,1,1)(0,1,1)[7] intercept   : AIC=906.649, Time=0.36 sec
#
# Best model:  ARIMA(0,1,1)(0,1,1)[7]
# Total fit time: 2.199 seconds
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                                 y   No. Observations:                   60
# Model:             SARIMAX(0, 1, 1)x(0, 1, 1, 7)   Log Likelihood                -449.338
# Date:                           Thu, 15 Oct 2020   AIC                            904.675
# Time:                                   16:14:00   BIC                            910.529
# Sample:                                        0   HQIC                           906.920
#                                             - 60
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.2194      0.148     -1.479      0.139      -0.510       0.071
# ma.S.L7       -0.7599      0.171     -4.456      0.000      -1.094      -0.426
# sigma2      1.784e+06   6.68e+05      2.671      0.008    4.75e+05    3.09e+06
# ===================================================================================
# Ljung-Box (Q):                      115.48   Jarque-Bera (JB):                 4.36
# Prob(Q):                              0.00   Prob(JB):                         0.11
# Heteroskedasticity (H):               1.12   Skew:                             0.02
# Prob(H) (two-sided):                  0.81   Kurtosis:                         1.58
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
