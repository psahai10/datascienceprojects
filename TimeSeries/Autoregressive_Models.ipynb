# %%
from statsmodels.tsa.arima_process import ArmaProcess
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['figure.dpi']=400
import numpy as np
ar = np.array([1,-0.9])
ma = np.array([1])
AR_object = ArmaProcess(ar, ma)
simulated_data = AR_object.generate_sample(nsample=1000)
plt.plot(simulated_data);

# %%
ar = np.array([1,0.9])
ma = np.array([1])
AR_object = ArmaProcess(ar, ma)
simulated_data = AR_object.generate_sample(nsample=1000)
plt.plot(simulated_data);

# %%
# Plot 1: AR parameter = +0.9
plt.subplot(2,1,1)
ar1 = np.array([1, -0.9])
ma1 = np.array([1])
AR_object1 = ArmaProcess(ar1, ma1)
simulated_data_1 = AR_object1.generate_sample(nsample=1000)
plt.plot(simulated_data_1)

# Plot 2: AR parameter = -0.9
plt.subplot(2,1,2)
ar2 = np.array([1, 0.9])
ma2 = np.array([1])
AR_object2 = ArmaProcess(ar2, ma2)
simulated_data_2 = AR_object2.generate_sample(nsample=1000)
plt.plot(simulated_data_2)
plt.show()

# %%
ar1 = np.array([1,-0.9])
ma1 = np.array([1])
AR_object1 = ArmaProcess(ar1, ma1)
simulated_data_1 = AR_object1.generate_sample(nsample=1000)

ar2 = np.array([1,0.9])
ma2 = np.array([1])
AR_object2 = ArmaProcess(ar2, ma2)
simulated_data_2 = AR_object2.generate_sample(nsample=1000)

ar3 = np.array([1,0.3])
ma3 = np.array([1])
AR_object3 = ArmaProcess(ar3, ma3)
simulated_data_3 = AR_object3.generate_sample(nsample=1000)

# %%
from statsmodels.graphics.tsaplots import plot_acf

plot_acf(simulated_data_1, alpha=1, lags=20)
plt.show()

plot_acf(simulated_data_2, alpha=1, lags=20)
plt.show()

plot_acf(simulated_data_3, alpha=1, lags=20)
plt.show()

# %%
ar1 = np.array([1,-0.9])
ma1 = np.array([1])
AR_object1 = ArmaProcess(ar1, ma1)
simulated_data_1 = AR_object1.generate_sample(nsample=1000)

# %%
from statsmodels.tsa.arima_model import ARMA
mod = ARMA(simulated_data_1, order=(1,0))
result = mod.fit()
# Out:
# C:\Users\psahai\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)

# %%
print(result.summary())
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:                      y   No. Observations:                 1000
# Model:                     ARMA(1, 0)   Log Likelihood               -1452.014
# Method:                       css-mle   S.D. of innovations              1.033
# Date:                Sat, 10 Oct 2020   AIC                           2910.028
# Time:                        09:22:42   BIC                           2924.752
# Sample:                             0   HQIC                          2915.624
#
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2167      0.299     -0.724      0.469      -0.803       0.370
# ar.L1.y        0.8918      0.014     62.732      0.000       0.864       0.920
#                                     Roots
# ...
#                   Real          Imaginary           Modulus         Frequency
# ...

# %%
print("When the true phi=0.9, the estimate of phi (and the constant) are:")
print(result.params)
# Out:
# When the true phi=0.9, the estimate of phi (and the constant) are:
# [-0.21670488  0.89179137]

# %%
# Import the ARMA module from statsmodels
from statsmodels.tsa.arima_model import ARMA

# Forecast the first AR(1) model
mod = ARMA(simulated_data_1, order=(1,0))
res = mod.fit()
res.plot_predict(start=990, end=1010)
plt.show()
# Out:
# C:\Users\psahai\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)

# %%
import pandas as pd
Date = ['1962-12-31', '1963-12-31', '1964-12-31', '1965-12-31',
               '1966-12-31', '1967-12-31', '1968-12-31', '1969-12-31',
               '1970-12-31', '1971-12-31', '1972-12-31', '1973-12-31',
               '1974-12-31', '1975-12-31', '1976-12-31', '1977-12-31',
               '1978-12-31', '1979-12-31', '1980-12-31', '1981-12-31',
               '1982-12-31', '1983-12-31', '1984-12-31', '1985-12-31',
               '1986-12-31', '1987-12-31', '1988-12-31', '1989-12-31',
               '1990-12-31', '1991-12-31', '1992-12-31', '1993-12-31',
               '1994-12-31', '1995-12-31', '1996-12-31', '1997-12-31',
               '1998-12-31', '1999-12-31', '2000-12-31', '2001-12-31',
               '2002-12-31', '2003-12-31', '2004-12-31', '2005-12-31',
               '2006-12-31', '2007-12-31', '2008-12-31', '2009-12-31',
               '2010-12-31', '2011-12-31', '2012-12-31', '2013-12-31',
               '2014-12-31', '2015-12-31', '2016-12-31', '2017-12-31']
Interest_rate = [3.85,  4.14,  4.21,  4.65,  4.64,  5.7 ,  6.16,  7.88,  6.5 ,
        5.89,  6.41,  6.9 ,  7.4 ,  7.76,  6.81,  7.78,  9.15, 10.33,
       12.43, 13.98, 10.36, 11.82, 11.55,  9.  ,  7.23,  8.83,  9.14,
        7.93,  8.08,  6.71,  6.7 ,  5.83,  7.84,  5.58,  6.43,  5.75,
        4.65,  6.45,  5.12,  5.07,  3.83,  4.27,  4.24,  4.39,  4.71,
        4.04,  2.25,  3.85,  3.3 ,  1.89,  1.78,  3.04,  2.17,  2.27,
        2.45,  2.16]

dic = {'Date': Date, 'Int_rate' : Interest_rate}

df = pd.DataFrame(dic)

# %%
df['Date'] = pd.to_datetime(df['Date'], errors = 'coerce')
df.set_index('Date', inplace=True)
df['Int_rate'] = pd.to_numeric(df['Int_rate'], errors='coerce')

# %%
 df.head()
# Out:
#             Int_rate
# Date
# 1962-12-31      3.85
# 1963-12-31      4.14
# 1964-12-31      4.21
# 1965-12-31      4.65
# 1966-12-31      4.64

# %%
from statsmodels.tsa.arima_model import ARMA

mod = ARMA(df, order=(1,0))
res = mod.fit()

res.plot_predict(start=0, end='2022')
plt.legend(fontsize=8)
plt.show()
# Out:
# C:\Users\psahai\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# ...

# %%
simulated_data = [5.        , 4.77522278, 5.60354317, 5.96406402, 5.97965372,
       6.02771876, 5.5470751 , 5.19867084, 5.01867859, 5.50452928,
       5.89293842, 4.6220103 , 5.06137835, 5.33377592, 5.09333293,
       5.37389022, 4.9657092 , 5.57339283, 5.48431854, 4.68588587,
       5.25218625, 4.34800798, 4.34544412, 4.72362568, 4.12582912,
       3.54622069, 3.43999885, 3.77116252, 3.81727011, 4.35256176,
       4.13664247, 3.8745768 , 4.01630403, 3.71276593, 3.55672457,
       3.07062647, 3.45264414, 3.28123729, 3.39193866, 3.02947806,
       3.88707349, 4.28776889, 3.47360734, 3.33260631, 3.09729579,
       2.94652178, 3.50079273, 3.61020341, 4.23021143, 3.94289347,
       3.58422345, 3.18253962, 3.26132564, 3.19777388, 3.43527681,
       3.37204482]

# %%
simulated_data = pd.DataFrame(simulated_data)
simulated_data.plot(grid=True)
plt.plot()
# Out:
# []

# %%
from statsmodels.graphics.tsaplots import plot_acf
fig, axes = plt.subplots(2,1)
fig = plot_acf(df, alpha=1, lags=12, ax=axes[0])
fig = plot_acf(simulated_data, alpha=1, lags=12, ax=axes[1])

axes[0].set_title("Interest Rate Data")
axes[1].set_title("Simulated Random Walk Data")
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
ar1 = np.array([1,-0.6])
ma1 = np.array([1])
AR_object1 = ArmaProcess(ar1, ma1)
simulated_data_1 = AR_object1.generate_sample(nsample=5000)

ar2 = np.array([1,-0.6, -0.3])
ma2 = np.array([1])
AR_object2 = ArmaProcess(ar2, ma2)
simulated_data_2 = AR_object2.generate_sample(nsample=5000)

ar3 = np.array([1,-0.6, -0.1, -0.075])
ma3 = np.array([1])
AR_object3 = ArmaProcess(ar3, ma3)
simulated_data_3 = AR_object3.generate_sample(nsample=5000)

import numpy as np
noise = np.random.normal(0,1,5000)
noise = pd.DataFrame(noise)
noise.columns = ['noise']
noise.head()
# Out:
#       noise
# 0 -0.968560
# 1  0.688223
# 2 -0.029939
# 3 -2.045145
# 4 -0.487782

# %%
from statsmodels.graphics.tsaplots import plot_pacf
import matplotlib.pyplot as plt

fig, ((ax1, ax2), (ax3,ax4)) = plt.subplots(2,2, figsize=(12,8))
fig = plot_pacf(simulated_data_1, alpha=0.05, lags=20, ax=ax1)
fig = plot_pacf(simulated_data_2, alpha=0.05, lags=20, ax=ax2)
fig = plot_pacf(simulated_data_3, alpha=0.05, lags=20, ax=ax3)
fig = plot_pacf(noise, alpha=0.05, lags=20, ax=ax4)

ax1.set_title("AR1")
ax2.set_title("AR2")
ax3.set_title("AR3")
ax4.set_title("White noise")

plt.show()

# %%
from statsmodels.tsa.arima_model import ARMA
mod = ARMA(simulated_data_1, order=(1,0))
result = mod.fit()
result.summary()
# Out:
# C:\Users\psahai\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ...
