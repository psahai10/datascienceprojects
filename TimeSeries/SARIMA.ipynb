# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['figure.dpi']=400
from statsmodels.tsa.stattools import adfuller

# %%
Y = [[-2.59864025e+02],
       [ 6.51865698e+02],
       [ 5.34675686e+01],
       [-4.18111488e+02],
       [ 4.59277647e+02],
       [ 2.57203202e+03],
       [ 8.97836544e+02],
       [-1.36469431e+02],
       [ 7.93772122e+02],
       [-1.78415048e+00],
       [-4.64574053e+02],
       [ 5.62645093e+02],
       [ 2.65000006e+03],
       [ 8.06978422e+02],
       [-3.69455084e+02],
       [ 8.94772774e+02],
       [-1.96310554e+02],
       [-6.14967843e+02],
       [ 8.12466743e+02],
       [ 3.04462880e+03],
       [ 7.62260732e+02],
       [-4.45115799e+02],
       [ 9.84908766e+02],
       [-2.01131580e+02],
       [-8.79643444e+02],
       [ 7.36467876e+02],
       [ 3.10841365e+03],
       [ 5.33855305e+02],
       [-5.38817700e+02],
       [ 1.19195776e+03],
       [-3.49752069e+02],
       [-1.20274695e+03],
       [ 8.61098329e+02],
       [ 2.76710341e+03],
       [ 7.66804377e+02],
       [-1.83155373e+02],
       [ 1.26726907e+03],
       [-5.02552098e+02],
       [-1.35530287e+03],
       [ 9.46849188e+02],
       [ 3.06455643e+03],
       [ 7.80529928e+02],
       [ 7.28322959e+01],
       [ 1.20650422e+03],
       [-3.70510005e+02],
       [-1.37824887e+03],
       [ 7.74558933e+02],
       [ 3.17043642e+03],
       [ 1.04240573e+03],
       [ 2.79212413e+02],
       [ 1.37623491e+03],
       [-1.95778657e+02],
       [-1.64372854e+03],
       [ 9.41633700e+02],
       [ 3.15891275e+03],
       [ 1.25084687e+03],
       [ 2.81856875e+02],
       [ 1.47068261e+03],
       [ 4.68504640e+01],
       [-1.42510478e+03],
       [ 5.64673871e+02],
       [ 2.76462291e+03],
       [ 1.46106522e+03],
       [ 2.27337552e+02],
       [ 1.77913564e+03],
       [ 2.67191173e+02],
       [-1.49964285e+03],
       [ 6.92547385e+02],
       [ 2.29177211e+03],
       [ 1.40681137e+03],
       [-2.29267151e+02],
       [ 1.61698096e+03],
       [ 4.81373669e+02],
       [-1.51388988e+03],
       [ 5.60489971e+02],
       [ 1.80330384e+03],
       [ 1.20710345e+03],
       [-3.41260693e+02],
       [ 1.35545588e+03],
       [ 5.53352601e+02],
       [-1.76446157e+03],
       [ 2.59405951e+02],
       [ 1.60686642e+03],
       [ 1.27883325e+03],
       [-2.61939712e+02],
       [ 1.20816919e+03],
       [ 8.51582733e+02],
       [-1.60988692e+03],
       [ 3.48293878e+02],
       [ 1.38068392e+03]]
Y = [x.pop() for x in Y]
dates = pd.date_range(start ='2013-01-01',  
         end ='2013-03-31', freq ='1D')
dic = {'dates':dates, 'Y':Y}
df1 = pd.DataFrame(dic)
df1.set_index('dates', inplace=True)
df1.head()
# Out:
#                      Y
# dates
# 2013-01-01 -259.864025
# 2013-01-02  651.865698
# 2013-01-03   53.467569
# 2013-01-04 -418.111488
# 2013-01-05  459.277647

# %%
Y = [[-1664.27414512],
       [-1797.40478094],
       [-2108.94290474],
       [-2611.18691925],
       [-3025.79191219],
       [-2766.80645938],
       [-2867.26689309],
       [-3411.73271047],
       [-3704.73856747],
       [-3790.30023061],
       [-4503.62058775],
       [-4315.39386631],
       [-5273.37225945],
       [-5382.99382281],
       [-5747.1123498 ],
       [-6112.54940002],
       [-6638.50041868],
       [-6563.0824711 ],
       [-6382.73706092],
       [-6961.29725345],
       [-6970.86445324],
       [-7262.19367887],
       [-6999.68769475],
       [-7267.85949127],
       [-6980.63861186],
       [-7279.23224061],
       [-7171.87412765],
       [-7617.84594245],
       [-7089.12982688],
       [-7779.37757505],
       [-7411.67189878],
       [-8516.55702272],
       [-8558.8171578 ],
       [-8915.35559698],
       [-8828.1061628 ],
       [-8621.67280318],
       [-8390.78065792],
       [-8545.12416502],
       [-8154.56089635],
       [-8189.85710777],
       [-8266.0885635 ],
       [-8347.12488275],
       [-8514.2637935 ],
       [-8151.58683191],
       [-8305.67375624],
       [-7907.70808935],
       [-7817.95582426],
       [-7146.49417746],
       [-6911.61109585],
       [-6455.39657972],
       [-6029.85239888],
       [-6082.83407734],
       [-5903.25171202],
       [-5473.16848339],
       [-5449.17359016],
       [-5426.59254858],
       [-5776.58792379],
       [-5297.30107451],
       [-5650.82654116],
       [-5275.97693468],
       [-4926.6588361 ],
       [-4835.70144674],
       [-4661.14003147],
       [-4122.19787904],
       [-3942.49061823],
       [-3808.97323028],
       [-3468.52174809],
       [-3626.32764183],
       [-3252.35425437],
       [-3382.46483813],
       [-3248.64284203],
       [-3328.30692984],
       [-3460.13972001],
       [-3613.44139367],
       [-3614.81825977],
       [-3837.39652086],
       [-3756.38707189],
       [-3664.46491005],
       [-3676.91128294],
       [-4159.40017133]]
Y = [x.pop() for x in Y]
dates = pd.date_range(start ='2013-01-01',  
         end ='2013-03-21', freq ='1D')
dic = {'dates':dates, 'Y':Y}
df2 = pd.DataFrame(dic)
df2.set_index('dates', inplace=True)
df2.head()
# Out:
#                       Y
# dates
# 2013-01-01 -1664.274145
# 2013-01-02 -1797.404781
# 2013-01-03 -2108.942905
# 2013-01-04 -2611.186919
# 2013-01-05 -3025.791912

# %%
Y = [[ 2141.49608911],
       [ 1557.63562198],
       [ 2715.08051599],
       [ 1313.53998506],
       [  777.62126548],
       [ 2476.38434035],
       [ 2640.64328966],
       [ 2415.59816357],
       [ 1843.88992223],
       [ 1946.76226576],
       [ 2190.80917857],
       [ 2421.96020884],
       [ 5287.33363674],
       [ 4873.03863905],
       [ 6134.55883261],
       [ 4659.42450305],
       [ 3983.96796691],
       [ 5699.32384687],
       [ 6003.28914891],
       [ 5810.21945848],
       [ 5422.54185597],
       [ 5585.16629908],
       [ 5849.12553586],
       [ 6151.71045931],
       [ 9203.41787175],
       [ 8623.91967378],
       [ 9859.84601136],
       [ 8293.20694763],
       [ 7491.61647521],
       [ 9013.13825732],
       [ 9285.11760915],
       [ 9148.34540439],
       [ 8582.1352383 ],
       [ 8788.62613465],
       [ 9045.22129035],
       [ 9375.16652108],
       [12368.81373799],
       [11716.06237952],
       [12989.06730428],
       [11395.0245482 ],
       [10676.02828206],
       [12216.71386523],
       [12579.40420808],
       [12396.39663651],
       [12041.16852461],
       [12356.67656153],
       [12554.11838046],
       [12901.76842995],
       [15781.61381719],
       [15106.70862542],
       [16339.11998361],
       [14705.44830276],
       [14039.55685001],
       [15448.16512021],
       [15628.40150321],
       [15342.48987978],
       [14863.1542345 ],
       [15165.35881853],
       [15369.00450331],
       [15733.87682609],
       [18507.24647396],
       [17757.6184722 ],
       [18980.29135515],
       [17364.86477823],
       [16977.88746733],
       [18468.01866511],
       [18756.46144603],
       [18606.62747277],
       [18228.26578336],
       [18481.86490427],
       [18543.55932036],
       [18938.82029813],
       [21818.72284919],
       [21081.84037572],
       [22313.73027795],
       [20751.23955022],
       [20316.20533127],
       [21761.59293181],
       [21861.82969723],
       [21510.96665819],
       [21102.29017729],
       [21404.69073067],
       [21528.0165631 ],
       [22004.03658912],
       [25033.3528865 ],
       [24455.42960667],
       [25831.4483193 ],
       [24554.37792112],
       [24371.79724868],
       [25742.60960716],
       [25772.6239273 ],
       [25365.07046559],
       [24976.20667557],
       [25299.66705602],
       [25521.25830863],
       [26135.71369843],
       [29183.63440899],
       [28621.21362327],
       [30025.35407697],
       [28766.14626826]]

Y = [x.pop() for x in Y]
dates = pd.date_range(start ='2013-01-01',  
         end ='2013-04-10', freq ='1D')
dic = {'dates':dates, 'Y':Y}
df3 = pd.DataFrame(dic)
df3.set_index('dates', inplace=True)
df3.head()
# Out:
#                       Y
# dates
# 2013-01-01  2141.496089
# 2013-01-02  1557.635622
# 2013-01-03  2715.080516
# 2013-01-04  1313.539985
# 2013-01-05   777.621265

# %%
df1.plot()

# %%
df2.plot()

# %%
df3.plot()

# %%
result = adfuller(df1['Y'])
print('ADF statistic is: {:.2f}'.format(result[0]))
print('p value is: {:.2f}'.format(result[1]))
print('Minimum adfuller value required for 0.05 significance is: {:.2f}'.format(result[4].get('5%')))
# Out:
# ADF statistic is: -0.88
# p value is: 0.80
# Minimum adfuller value required for 0.05 significance is: -2.90

# %%
result = adfuller(df2['Y'])
print('ADF statistic is: {:.2f}'.format(result[0]))
print('p value is: {:.2f}'.format(result[1]))
print('Minimum adfuller value required for 0.05 significance is: {:.2f}'.format(result[4].get('5%')))
# Out:
# ADF statistic is: -1.78
# p value is: 0.39
# Minimum adfuller value required for 0.05 significance is: -2.90

# %%
result = adfuller(df3['Y'])
print('ADF statistic is: {:.2f}'.format(result[0]))
print('p value is: {:.2f}'.format(result[1]))
print('Minimum adfuller value required for 0.05 significance is: {:.2f}'.format(result[4].get('5%')))
# Out:
# ADF statistic is: 1.03
# p value is: 0.99
# Minimum adfuller value required for 0.05 significance is: -2.90

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomp_results = seasonal_decompose(df1['Y'], freq=6)
decomp_results.plot()
plt.show()
# Out:
# C:\Users\psahai\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomp_results = seasonal_decompose(df2['Y'], freq=6)
decomp_results.plot()
plt.show()
# Out:
# C:\Users\psahai\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomp_results = seasonal_decompose(df3['Y'], freq=6)
decomp_results.plot()
plt.show()
# Out:
# C:\Users\psahai\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
model = SARIMAX(df1, order=(1,0,0), seasonal_order=(1,1,0,7))
results = model.fit()
print(results.summary())
# Out:
#                                      SARIMAX Results
# ...
# Dep. Variable:                                 Y   No. Observations:                   90
# Model:             SARIMAX(1, 0, 0)x(1, 1, 0, 7)   Log Likelihood                -556.243
# Date:                           Thu, 15 Oct 2020   AIC                           1118.486
# Time:                                   14:28:06   BIC                           1125.742
# Sample:                               01-01-2013   HQIC                          1121.401
#                                     - 03-31-2013
# Covariance Type:                             opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1032      0.103      1.002      0.316      -0.099       0.305
# ar.S.L7        0.2781      0.104      2.665      0.008       0.074       0.483
# ...

# %%
model = SARIMAX(df2, order=(2,1,1), seasonal_order=(1,0,0,4))
results = model.fit()
print(results.summary())
# Out:
# C:\Users\psahai\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\Users\psahai\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
#                                      SARIMAX Results
# ...
# Dep. Variable:                                  Y   No. Observations:                   80
# Model:             SARIMAX(2, 1, 1)x(1, 0, [], 4)   Log Likelihood                -560.340
# Date:                            Thu, 15 Oct 2020   AIC                           1130.679
# Time:                                    14:29:00   BIC                           1142.526
# Sample:                                01-01-2013   HQIC                          1135.426
#                                      - 03-21-2013
# ...

# %%
model = SARIMAX(df3, order=(1,1,0), seasonal_order=(0,1,1,12))
results = model.fit()
print(results.summary())

# %%
people_employed = [[5985.7],
       [6040.6],
       [6054.2],
       [6038.3],
       [6031.3],
       [6036.1],
       [6005.4],
       [6024.3],
       [6045.9],
       [6033.8],
       [6125.4],
       [5971.3],
       [6050.7],
       [6096.2],
       [6087.7],
       [6075.6],
       [6095.7],
       [6103.9],
       [6078.5],
       [6157.8],
       [6164. ],
       [6188.8],
       [6257.2],
       [6112.9],
       [6207.2],
       [6278.7],
       [6224.9],
       [6273.4],
       [6269.9],
       [6314.1],
       [6281.4],
       [6360. ],
       [6320.2],
       [6342. ],
       [6426.6],
       [6253. ],
       [6356.5],
       [6428.1],
       [6426.3],
       [6412.4],
       [6413.9],
       [6425.3],
       [6393.7],
       [6502.7],
       [6445.3],
       [6433.3],
       [6506.9],
       [6355.5],
       [6432.4],
       [6497.4],
       [6431.6],
       [6440.9],
       [6414.3],
       [6425.9],
       [6379.3],
       [6443.5],
       [6421.1],
       [6367. ],
       [6370.2],
       [6172.2],
       [6264.1],
       [6310.4],
       [6254.5],
       [6272.8],
       [6266.5],
       [6295. ],
       [6241.1],
       [6358.2],
       [6336.2],
       [6377.5],
       [6456.4],
       [6251.4],
       [6365.4],
       [6503.2],
       [6477.6],
       [6489.7],
       [6499. ],
       [6528.7],
       [6466.1],
       [6579.8],
       [6553.2],
       [6576.1],
       [6636. ],
       [6452.4],
       [6595.7],
       [6657.4],
       [6588.8],
       [6658. ],
       [6659.4],
       [6703.4],
       [6675.6],
       [6814.7],
       [6771.1],
       [6882. ],
       [6910.8],
       [6753.6],
       [6861.9],
       [6961.9],
       [6997.9],
       [6979. ],
       [7007.7],
       [6991.5],
       [6918.6],
       [7040.6],
       [7030.4],
       [7034.2],
       [7116.8],
       [6902.5],
       [7022.3],
       [7133.4],
       [7109.6],
       [7103.6],
       [7128.9],
       [7175.6],
       [7092.3],
       [7186.5],
       [7177.4],
       [7182.2],
       [7330.7],
       [7169.4],
       [7247.4],
       [7397.4],
       [7383.4],
       [7354.9],
       [7378.3],
       [7383.1],
       [7353.4],
       [7503.2],
       [7477.3],
       [7508.7],
       [7622.9],
       [7424.9],
       [7569.7],
       [7638.3],
       [7683.2],
       [7729.3],
       [7720.5],
       [7751.8],
       [7727.6],
       [7854.4],
       [7817.8],
       [7870.7],
       [7941.6],
       [7712.6],
       [7809.1],
       [7877.5],
       [7894.3],
       [7916.1],
       [7910. ],
       [7932.9],
       [7825. ],
       [7925.5],
       [7870.5],
       [7849.9],
       [7941.2],
       [7668.8],
       [7739.3],
       [7746.5],
       [7750.5]]
people_employed = [x.pop() for x in people_employed]
dates = pd.date_range(start ='1978-01-01',  
         end ='1991-04-01', freq ='1M')
dic = {'dates':dates, 'people_employed':people_employed}
aus_employment = pd.DataFrame(dic)
aus_employment.set_index('dates', inplace=True)
aus_employment.head()
# Out:
#             people_employed
# dates
# 1978-01-31           5985.7
# 1978-02-28           6040.6
# 1978-03-31           6054.2
# 1978-04-30           6038.3
# 1978-05-31           6031.3

# %%
aus_employment.plot()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomp_results = seasonal_decompose(aus_employment['people_employed'], freq=12)
decomp_results.plot()
plt.show()
# Out:
# C:\Users\psahai\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead

# %%
aus_employment_diff = aus_employment.diff().diff(12).dropna()

# %%
aus_employment_diff.plot()

# %%
result = adfuller(aus_employment_diff['people_employed'])
print('ADF statistic is: {:.2f}'.format(result[0]))
print('p value is: {:.2f}'.format(result[1]))
print('Minimum adfuller value required for 0.05 significance is: {:.2f}'.format(result[4].get('5%')))
# Out:
# ADF statistic is: -4.18
# p value is: 0.00
# Minimum adfuller value required for 0.05 significance is: -2.88

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

fig, (ax1, ax2) = plt.subplots(2,1,figsize=(8,6))
plot_acf(aus_employment_diff, lags=11, zero=False, ax=ax1)
plot_pacf(aus_employment_diff, lags=11, zero=False, ax=ax2)
plt.show()

# %%
lags = [12, 24, 36, 48, 60]
fig, (ax1, ax2) = plt.subplots(2,1,figsize=(8,6))
plot_acf(aus_employment_diff, lags=lags, ax=ax1)
plot_pacf(aus_employment_diff, lags=lags, ax=ax2)
plt.show()

# %%
employment = [[374.5],
       [380.2],
       [384.6],
       [360.6],
       [354.4],
       [357.4],
       [367. ],
       [375.7],
       [381. ],
       [381.2],
       [383. ],
       [384.3],
       [387. ],
       [391.7],
       [396. ],
       [374. ],
       [370.4],
       [373.2],
       [381.1],
       [389.9],
       [394.6],
       [394. ],
       [397. ],
       [397.2],
       [399.4]]
employment = [x.pop() for x in employment]
dates = pd.date_range(start ='1973-10-01',  
         end ='1975-11-01', freq ='1M')
dic = {'dates':dates, 'employment':employment}
wisconsin_test = pd.DataFrame(dic)
wisconsin_test.set_index('dates', inplace=True)
wisconsin_test.head()
# Out:
#             employment
# dates
# 1973-10-31       374.5
# 1973-11-30       380.2
# 1973-12-31       384.6
# 1974-01-31       360.6
# 1974-02-28       354.4

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
model1 = SARIMAX(wisconsin_test, order=(0,2,0), seasonal_order=(0,1,0,12))
arima_results = model1.fit()
print(arima_results.summary())
# Out:
#                                      SARIMAX Results
# ...
# Dep. Variable:                         employment   No. Observations:                   25
# Model:             SARIMAX(0, 2, 0)x(0, 1, 0, 12)   Log Likelihood                 -20.957
# Date:                            Thu, 15 Oct 2020   AIC                             43.914
# Time:                                    16:02:06   BIC                             44.312
# Sample:                                10-31-1973   HQIC                            43.663
#                                      - 10-31-1975
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         2.6445      1.739      1.521      0.128      -0.764       6.053
# ...
# Ljung-Box (L1) (Q):                   0.34   Jarque-Bera (JB):                 0.83
# ...

# %%
model2 = SARIMAX(wisconsin_test, order=(3,1,2))
sarima_results = model2.fit()
print(sarima_results.summary())
# Out:
# C:\Users\psahai\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   % freq, ValueWarning)
# C:\Users\psahai\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:527: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   % freq, ValueWarning)
#                                SARIMAX Results
# ...
# Dep. Variable:             employment   No. Observations:                   25
# Model:               SARIMAX(3, 1, 2)   Log Likelihood                 -81.286
# Date:                Thu, 15 Oct 2020   AIC                            174.571
# Time:                        16:02:07   BIC                            181.640
# Sample:                    10-31-1973   HQIC                           176.447
#                          - 10-31-1975
# Covariance Type:                  opg
# ...

# %%
# Create ARIMA mean forecast
arima_pred = arima_results.get_forecast(steps=25)
arima_mean = arima_pred.predicted_mean

# Create SARIMA mean forecast
sarima_pred = sarima_results.get_forecast(steps=25)
sarima_mean = sarima_pred.predicted_mean

# Plot mean ARIMA and SARIMA predictions and observed
plt.plot(dates, sarima_mean, label='SARIMA')
plt.plot(dates, arima_mean, label='ARIMA')
plt.plot(wisconsin_test, label='observed')
plt.legend()
plt.show()

# %%
data =wisconsin_test

# %%
fig, axes = plt.subplots(2, 1, figsize=(10,5), dpi=100, sharex=True)

# Usual Differencing
axes[0].plot(data[:], label='Original Series')
axes[0].plot(data[:].diff(1), label='Usual Differencing')
axes[0].legend(loc='upper left', fontsize=10)


# Seasinal Dei
axes[1].plot(data[:], label='Original Series')
axes[1].plot(data[:].diff(6), label='Seasonal Differencing', color='green')
plt.legend(loc='upper left', fontsize=10)
plt.show()

# %%
# !pip3 install pyramid-arima
import pmdarima as pm

# Seasonal - fit stepwise auto-ARIMA
smodel = pm.auto_arima(data, start_p=1, start_q=1,
                         test='adf',
                         max_p=3, max_q=3, m=12,
                         start_P=0, seasonal=True,
                         d=None, D=1, trace=True,
                         error_action='ignore',  
                         suppress_warnings=True, 
                         stepwise=True)

smodel.summary()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-76-d5d6c6eec7ee> in <module>
#       1 # !pip3 install pyramid-arima
# ----> 2 import pmdarima as pm
#       3
#       4 # Seasonal - fit stepwise auto-ARIMA
#       5 smodel = pm.auto_arima(data, start_p=1, start_q=1,
#
# ~\Anaconda3\lib\site-packages\pmdarima\__init__.py in <module>
#      49
#      50     # Stuff we want at top-level
# ---> 51     from .arima import auto_arima, ARIMA, AutoARIMA, StepwiseContext, decompose
#      52     from .utils import acf, autocorr_plot, c, pacf, plot_acf, plot_pacf, \
#      53         tsdisplay
#
# ~\Anaconda3\lib\site-packages\pmdarima\arima\__init__.py in <module>
#       4
#       5 from .approx import *
# ----> 6 from .arima import *
#       7 from .auto import *
#       8 from .utils import *
#
# ~\Anaconda3\lib\site-packages\pmdarima\arima\arima.py in <module>
# ...
